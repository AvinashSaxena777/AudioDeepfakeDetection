# %% [markdown]
# # Wav2Vec2 Model for Deepfake Audio Detection
#
# ## Summary of Key Processing Steps in Wav2Vec2
#
# 1. Directly processes raw audio using convolutional layers in the feature encoder.
# 2. Utilizes a Transformer to capture temporal relationships across the audio sequence.
# 3. Fine-tunes easily for classification tasks by adding a lightweight classification head.
# 4. Pre-trained on vast unlabeled audio data, enabling it to perform well with limited labeled data for classification.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/Datasets/dataset.zip /content/

# %%
# !unzip /content/dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: selected_train_audio/spoof/LA_T_2850612.flac
#   inflating: selected_train_audio/spoof/LA_T_1282219.flac
#   inflating: selected_train_audio/spoof/LA_T_4512688.flac
#   inflating: selected_train_audio/spoof/LA_T_2307693.flac
#   inflating: selected_train_audio/spoof/LA_T_3897361.flac
#   inflating: selected_train_audio/spoof/LA_T_1930732.flac
#   inflating: selected_train_audio/spoof/LA_T_3070376.flac
#   inflating: selected_train_audio/spoof/LA_T_1365409.flac
#   inflating: selected_train_audio/spoof/LA_T_4091103.flac
#   inflating: selected_train_audio/spoof/LA_T_2599425.flac
#   inflating: selected_train_audio/spoof/LA_T_3891659.flac
#   inflating: selected_train_audio/spoof/LA_T_4238059.flac
#   inflating: selected_train_audio/spoof/LA_T_4761800.flac
#   inflating: selected_train_audio/spoof/LA_T_1674369.flac
#   inflating: selected_train_audio/spoof/LA_T_3314176.flac
#   inflating: selected_train_audio/spoof/LA_T_1784183.flac
#   inflating: selected_train_audio/spoof/LA_T_1206739.flac
#   inflating: selected_train_audio/spoof/LA_T_1603900.flac
#   inflating: selected_train_audio/spoof/LA_T_2196517.flac
#   inflating: selected_train_audio/spoof/LA_T_4230020.flac
#   inflating: selected_train_audio/spoof/LA_T_1412465.flac
#   inflating: selected_train_audio/spoof/LA_T_3887076.flac
#   inflating: selected_train_audio/spoof/LA_T_1268827.flac
#   inflating: selected_train_audio/spoof/LA_T_3712476.flac
#   inflating: selected_train_audio/spoof/LA_T_1559331.flac
#   inflating: selected_train_audio/spoof/LA_T_3689990.flac
#   inflating: selected_train_audio/spoof/LA_T_3357684.flac
#   inflating: selected_train_audio/spoof/LA_T_3176220.flac
#   inflating: selected_train_audio/spoof/LA_T_4666771.flac
#   inflating: selected_train_audio/spoof/LA_T_4585479.flac
#   inflating: selected_train_audio/spoof/LA_T_4543888.flac
#   inflating: selected_train_audio/spoof/LA_T_4719244.flac
#   inflating: selected_train_audio/spoof/LA_T_4134163.flac
#   inflating: selected_train_audio/spoof/LA_T_3459054.flac
#   inflating: selected_train_audio/spoof/LA_T_3102990.flac
#   inflating: selected_train_audio/spoof/LA_T_1895278.flac
#   inflating: selected_train_audio/spoof/LA_T_1660615.flac
#   inflating: selected_train_audio/spoof/LA_T_2469017.flac
#   inflating: selected_train_audio/spoof/LA_T_1679817.flac
#   inflating: selected_train_audio/spoof/LA_T_2350109.flac
#   inflating: selected_train_audio/spoof/LA_T_2869592.flac
#   inflating: selected_train_audio/spoof/LA_T_1791424.flac
#   inflating: selected_train_audio/spoof/LA_T_1243390.flac
#   inflating: selected_train_audio/spoof/LA_T_1958248.flac
#   inflating: selected_train_audio/spoof/LA_T_4416679.flac
#   inflating: selected_train_audio/spoof/LA_T_2848953.flac
#   inflating: selected_train_audio/spoof/LA_T_3639417.flac
#   inflating: selected_train_audio/spoof/LA_T_3253358.flac
#   inflating: selected_train_audio/spoof/LA_T_4230097.flac
#   inflating: selected_train_audio/spoof/LA_T_2415385.flac
#   inflating: selected_train_audio/spoof/LA_T_1416691.flac
#   inflating: selected_train_audio/spoof/LA_T_1228221.flac
#   inflating: selected_train_audio/spoof/LA_T_3958843.flac
#   inflating: selected_train_audio/spoof/LA_T_1199774.flac
#   inflating: selected_train_audio/spoof/LA_T_4138434.flac
#   inflating: selected_train_audio/spoof/LA_T_2593029.flac
#   inflating: selected_train_audio/spoof/LA_T_4107974.flac
#   inflating: selected_train_audio/spoof/LA_T_4322946.flac
#   inflating: selected_train_audio/spoof/LA_T_2681186.flac
#   inflating: selected_train_audio/spoof/LA_T_3746344.flac
#   inflating: selected_train_audio/spoof/LA_T_1184665.flac
#   inflating: selected_train_audio/spoof/LA_T_3101159.flac
#   inflating: selected_train_audio/spoof/LA_T_4713072.flac
#   inflating: selected_train_audio/spoof/LA_T_3413283.flac
#   inflating: selected_train_audio/spoof/LA_T_1457116.flac
#   inflating: selected_train_audio/spoof/LA_T_4130504.flac
#   inflating: selected_train_audio/spoof/LA_T_4063190.flac
#   inflating: selected_train_audio/spoof/LA_T_3357172.flac
#   inflating: selected_train_audio/spoof/LA_T_2454840.flac
#   inflating: selected_train_audio/spoof/LA_T_3089008.flac
#   inflating: selected_train_audio/spoof/LA_T_2230106.flac
#   inflating: selected_train_audio/spoof/LA_T_2423846.flac
#   inflating: selected_train_audio/spoof/LA_T_2749986.flac
#   inflating: selected_train_audio/spoof/LA_T_2420983.flac
#   inflating: selected_train_audio/spoof/LA_T_3137970.flac
#   inflating: selected_train_audio/spoof/LA_T_4408459.flac
#   inflating: selected_train_audio/spoof/LA_T_3333121.flac
#   inflating: selected_train_audio/spoof/LA_T_2979349.flac
#   inflating: selected_train_audio/spoof/LA_T_2024720.flac
#   inflating: selected_train_audio/spoof/LA_T_3042376.flac
#   inflating: selected_train_audio/spoof/LA_T_2196391.flac
#   inflating: selected_train_audio/spoof/LA_T_1454585.flac
#   inflating: selected_train_audio/spoof/LA_T_1898988.flac
#   inflating: selected_train_audio/spoof/LA_T_2779402.flac
#   inflating: selected_train_audio/spoof/LA_T_3681710.flac
#   inflating: selected_train_audio/spoof/LA_T_4318203.flac
#   inflating: selected_train_audio/spoof/LA_T_3286480.flac
#   inflating: selected_train_audio/spoof/LA_T_1153405.flac
#   inflating: selected_train_audio/spoof/LA_T_4292983.flac
#   inflating: selected_train_audio/spoof/LA_T_1724943.flac
#   inflating: selected_train_audio/spoof/LA_T_4382452.flac
#   inflating: selected_train_audio/spoof/LA_T_1649598.flac
#   inflating: selected_train_audio/spoof/LA_T_4187586.flac
#   inflating: selected_train_audio/spoof/LA_T_1820653.flac
#   inflating: selected_train_audio/spoof/LA_T_2677838.flac
#   inflating: selected_train_audio/spoof/LA_T_1211236.flac
#   inflating: selected_train_audio/spoof/LA_T_3674944.flac
#   inflating: selected_train_audio/spoof/LA_T_1890957.flac
#   inflating: selected_train_audio/spoof/LA_T_1473010.flac
#   inflating: selected_train_audio/spoof/LA_T_1225792.flac
#   inflating: selected_train_audio/spoof/LA_T_3903626.flac
#   inflating: selected_train_audio/spoof/LA_T_1698884.flac
#   inflating: selected_train_audio/spoof/LA_T_3892421.flac
#   inflating: selected_train_audio/spoof/LA_T_3466888.flac
#   inflating: selected_train_audio/spoof/LA_T_2876368.flac
#   inflating: selected_train_audio/spoof/LA_T_1386590.flac
#   inflating: selected_train_audio/spoof/LA_T_2671922.flac
#   inflating: selected_train_audio/spoof/LA_T_1848422.flac
#   inflating: selected_train_audio/spoof/LA_T_2841809.flac
#   inflating: selected_train_audio/spoof/LA_T_4183341.flac
#   inflating: selected_train_audio/spoof/LA_T_3718123.flac
#   inflating: selected_train_audio/spoof/LA_T_4889584.flac
#   inflating: selected_train_audio/spoof/LA_T_3745671.flac
#   inflating: selected_train_audio/spoof/LA_T_2363231.flac
#   inflating: selected_train_audio/spoof/LA_T_1633985.flac
#   inflating: selected_train_audio/spoof/LA_T_3373109.flac
#   inflating: selected_train_audio/spoof/LA_T_4208666.flac
#   inflating: selected_train_audio/spoof/LA_T_4577264.flac
#   inflating: selected_train_audio/spoof/LA_T_3601630.flac
#   inflating: selected_train_audio/spoof/LA_T_3181178.flac
#   inflating: selected_train_audio/spoof/LA_T_4894341.flac
#   inflating: selected_train_audio/spoof/LA_T_1443885.flac
#   inflating: selected_train_audio/spoof/LA_T_2313160.flac
#   inflating: selected_train_audio/spoof/LA_T_1369550.flac
#   inflating: selected_train_audio/spoof/LA_T_2768227.flac
#   inflating: selected_train_audio/spoof/LA_T_3296160.flac
#   inflating: selected_train_audio/spoof/LA_T_3171910.flac
#   inflating: selected_train_audio/spoof/LA_T_1132475.flac
#   inflating: selected_train_audio/spoof/LA_T_2891055.flac
#   inflating: selected_train_audio/spoof/LA_T_1610571.flac
#   inflating: selected_train_audio/spoof/LA_T_2389354.flac
#   inflating: selected_train_audio/spoof/LA_T_1045827.flac
#   inflating: selected_train_audio/spoof/LA_T_2466608.flac
#   inflating: selected_train_audio/spoof/LA_T_3197112.flac
#   inflating: selected_train_audio/spoof/LA_T_3432355.flac
#   inflating: selected_train_audio/spoof/LA_T_3369291.flac
#   inflating: selected_train_audio/spoof/LA_T_2643094.flac
#   inflating: selected_train_audio/spoof/LA_T_3061203.flac
#   inflating: selected_train_audio/spoof/LA_T_3136810.flac
#   inflating: selected_train_audio/spoof/LA_T_4157075.flac
#   inflating: selected_train_audio/spoof/LA_T_1403848.flac
#   inflating: selected_train_audio/spoof/LA_T_3641391.flac
#   inflating: selected_train_audio/spoof/LA_T_2619404.flac
#   inflating: selected_train_audio/spoof/LA_T_3419604.flac
#   inflating: selected_train_audio/spoof/LA_T_2491691.flac
#   inflating: selected_train_audio/spoof/LA_T_4390799.flac
#   inflating: selected_train_audio/spoof/LA_T_2253635.flac
#   inflating: selected_train_audio/spoof/LA_T_2189841.flac
#   inflating: selected_train_audio/spoof/LA_T_3149957.flac
#   inflating: selected_train_audio/spoof/LA_T_3158539.flac
#   inflating: selected_train_audio/spoof/LA_T_2213663.flac
#   inflating: selected_train_audio/spoof/LA_T_3205362.flac
#   inflating: selected_train_audio/spoof/LA_T_1619535.flac
#   inflating: selected_train_audio/spoof/LA_T_2902832.flac
#   inflating: selected_train_audio/spoof/LA_T_4105496.flac
#   inflating: selected_train_audio/spoof/LA_T_1512473.flac
#   inflating: selected_train_audio/spoof/LA_T_4168222.flac
#   inflating: selected_train_audio/spoof/LA_T_3230827.flac
#   inflating: selected_train_audio/spoof/LA_T_3882016.flac
#   inflating: selected_train_audio/spoof/LA_T_3959473.flac
#   inflating: selected_train_audio/spoof/LA_T_3865996.flac
#   inflating: selected_train_audio/spoof/LA_T_2263368.flac
#   inflating: selected_train_audio/spoof/LA_T_2943067.flac
#   inflating: selected_train_audio/spoof/LA_T_3588087.flac
#   inflating: selected_train_audio/spoof/LA_T_4767881.flac
#   inflating: selected_train_audio/spoof/LA_T_2055119.flac
#   inflating: selected_train_audio/spoof/LA_T_1203411.flac
#   inflating: selected_train_audio/spoof/LA_T_2496003.flac
#   inflating: selected_train_audio/spoof/LA_T_3878732.flac
#   inflating: selected_train_audio/spoof/LA_T_1232606.flac
#   inflating: selected_train_audio/spoof/LA_T_2038563.flac
#   inflating: selected_train_audio/spoof/LA_T_4760598.flac
#   inflating: selected_train_audio/spoof/LA_T_2549731.flac
#   inflating: selected_train_audio/spoof/LA_T_4754661.flac
#   inflating: selected_train_audio/spoof/LA_T_3848261.flac
#   inflating: selected_train_audio/spoof/LA_T_3160797.flac
#   inflating: selected_train_audio/spoof/LA_T_2849741.flac
#   inflating: selected_train_audio/spoof/LA_T_4101449.flac
#   inflating: selected_train_audio/spoof/LA_T_2971035.flac
#   inflating: selected_train_audio/spoof/LA_T_2620382.flac
#   inflating: selected_train_audio/spoof/LA_T_2350171.flac
#   inflating: selected_train_audio/spoof/LA_T_2494059.flac
#   inflating: selected_train_audio/spoof/LA_T_2214499.flac
#   inflating: selected_train_audio/spoof/LA_T_3053046.flac
#   inflating: selected_train_audio/spoof/LA_T_4272829.flac
#   inflating: selected_train_audio/spoof/LA_T_1204308.flac
#   inflating: selected_train_audio/spoof/LA_T_2458418.flac
#   inflating: selected_train_audio/spoof/LA_T_1246037.flac
#   inflating: selected_train_audio/spoof/LA_T_2215571.flac
#   inflating: selected_train_audio/spoof/LA_T_4739602.flac
#   inflating: selected_train_audio/spoof/LA_T_4870666.flac
#   inflating: selected_train_audio/spoof/LA_T_2011697.flac
#   inflating: selected_train_audio/spoof/LA_T_1873241.flac
#   inflating: selected_train_audio/spoof/LA_T_4279641.flac
#   inflating: selected_train_audio/spoof/LA_T_1984878.flac
#   inflating: selected_train_audio/spoof/LA_T_1576430.flac
#   inflating: selected_train_audio/spoof/LA_T_3292496.flac
#   inflating: selected_train_audio/spoof/LA_T_3874584.flac
#   inflating: selected_train_audio/spoof/LA_T_1562058.flac
#   inflating: selected_train_audio/spoof/LA_T_4432519.flac
#   inflating: selected_train_audio/spoof/LA_T_3211664.flac
#   inflating: selected_train_audio/spoof/LA_T_2838332.flac
#   inflating: selected_train_audio/spoof/LA_T_2514091.flac
#   inflating: selected_train_audio/spoof/LA_T_1314910.flac
#   inflating: selected_train_audio/spoof/LA_T_1164518.flac
#   inflating: selected_train_audio/spoof/LA_T_3548105.flac
#   inflating: selected_train_audio/spoof/LA_T_4261334.flac
#   inflating: selected_train_audio/spoof/LA_T_2244112.flac
#   inflating: selected_train_audio/spoof/LA_T_1880729.flac
#   inflating: selected_train_audio/spoof/LA_T_3339055.flac
#   inflating: selected_train_audio/spoof/LA_T_4642214.flac
#   inflating: selected_train_audio/spoof/LA_T_4403972.flac
#   inflating: selected_train_audio/spoof/LA_T_1952833.flac
#   inflating: selected_train_audio/spoof/LA_T_3140595.flac
#   inflating: selected_train_audio/spoof/LA_T_3369995.flac
#   inflating: selected_train_audio/spoof/LA_T_2505548.flac
#   inflating: selected_train_audio/spoof/LA_T_4013431.flac
#   inflating: selected_train_audio/spoof/LA_T_2895790.flac
#   inflating: selected_train_audio/spoof/LA_T_3167638.flac
#   inflating: selected_train_audio/spoof/LA_T_1968330.flac
#   inflating: selected_train_audio/spoof/LA_T_4626344.flac
#   inflating: selected_train_audio/spoof/LA_T_4200645.flac
#   inflating: selected_train_audio/spoof/LA_T_3894262.flac
#   inflating: selected_train_audio/spoof/LA_T_3458660.flac
#   inflating: selected_train_audio/spoof/LA_T_4855570.flac
#   inflating: selected_train_audio/spoof/LA_T_1473901.flac
#   inflating: selected_train_audio/spoof/LA_T_4322092.flac
#   inflating: selected_train_audio/spoof/LA_T_3322867.flac
#   inflating: selected_train_audio/spoof/LA_T_4612737.flac
#   inflating: selected_train_audio/spoof/LA_T_4004910.flac
#   inflating: selected_train_audio/spoof/LA_T_1363785.flac
#   inflating: selected_train_audio/spoof/LA_T_3899066.flac
#   inflating: selected_train_audio/spoof/LA_T_1415854.flac
#   inflating: selected_train_audio/spoof/LA_T_2114020.flac
#   inflating: selected_train_audio/spoof/LA_T_2612668.flac
#   inflating: selected_train_audio/spoof/LA_T_3503831.flac
#   inflating: selected_train_audio/spoof/LA_T_2698180.flac
#   inflating: selected_train_audio/spoof/LA_T_2796431.flac
#   inflating: selected_train_audio/spoof/LA_T_1044167.flac
#   inflating: selected_train_audio/spoof/LA_T_4069817.flac
#   inflating: selected_train_audio/spoof/LA_T_4235407.flac
#   inflating: selected_train_audio/spoof/LA_T_4477504.flac
#   inflating: selected_train_audio/spoof/LA_T_2998149.flac
#   inflating: selected_train_audio/spoof/LA_T_2559276.flac
#   inflating: selected_train_audio/spoof/LA_T_2491082.flac
#   inflating: selected_train_audio/spoof/LA_T_1593993.flac
#   inflating: selected_train_audio/spoof/LA_T_3174897.flac
#   inflating: selected_train_audio/spoof/LA_T_4322576.flac
#   inflating: selected_train_audio/spoof/LA_T_3089779.flac
#   inflating: selected_train_audio/spoof/LA_T_4439548.flac
#   inflating: selected_train_audio/spoof/LA_T_3728852.flac
#   inflating: selected_train_audio/spoof/LA_T_4618692.flac
#   inflating: selected_train_audio/spoof/LA_T_2014308.flac
#   inflating: selected_train_audio/spoof/LA_T_4121219.flac
#   inflating: selected_train_audio/spoof/LA_T_3258185.flac
#   inflating: selected_train_audio/spoof/LA_T_3904124.flac
#   inflating: selected_train_audio/spoof/LA_T_1518053.flac
#   inflating: selected_train_audio/spoof/LA_T_4639176.flac
#   inflating: selected_train_audio/spoof/LA_T_3680830.flac
#   inflating: selected_train_audio/spoof/LA_T_2984639.flac
#   inflating: selected_train_audio/spoof/LA_T_3894358.flac
#   inflating: selected_train_audio/spoof/LA_T_1795340.flac
#   inflating: selected_train_audio/spoof/LA_T_3428349.flac
#   inflating: selected_train_audio/spoof/LA_T_4055078.flac
#   inflating: selected_train_audio/spoof/LA_T_4348646.flac
#   inflating: selected_train_audio/spoof/LA_T_1760440.flac
#   inflating: selected_train_audio/spoof/LA_T_2479331.flac
#   inflating: selected_train_audio/spoof/LA_T_2173067.flac
#   inflating: selected_train_audio/spoof/LA_T_4767849.flac
#   inflating: selected_train_audio/spoof/LA_T_2281986.flac
#   inflating: selected_train_audio/spoof/LA_T_3905536.flac
#   inflating: selected_train_audio/spoof/LA_T_2433369.flac
#   inflating: selected_train_audio/spoof/LA_T_2449288.flac
#   inflating: selected_train_audio/spoof/LA_T_3479506.flac
#   inflating: selected_train_audio/spoof/LA_T_2858380.flac
#   inflating: selected_train_audio/spoof/LA_T_2561977.flac
#   inflating: selected_train_audio/spoof/LA_T_2943017.flac
#   inflating: selected_train_audio/spoof/LA_T_1997992.flac
#   inflating: selected_train_audio/spoof/LA_T_3100854.flac
#   inflating: selected_train_audio/spoof/LA_T_1226612.flac
#   inflating: selected_train_audio/spoof/LA_T_3577726.flac
#   inflating: selected_train_audio/spoof/LA_T_4480170.flac
#   inflating: selected_train_audio/spoof/LA_T_1926234.flac
#   inflating: selected_train_audio/spoof/LA_T_3266132.flac
#   inflating: selected_train_audio/spoof/LA_T_4101390.flac
#   inflating: selected_train_audio/spoof/LA_T_3394997.flac
#   inflating: selected_train_audio/spoof/LA_T_2809893.flac
#   inflating: selected_train_audio/spoof/LA_T_4036171.flac
#   inflating: selected_train_audio/spoof/LA_T_4460204.flac
#   inflating: selected_train_audio/spoof/LA_T_1916240.flac
#   inflating: selected_train_audio/spoof/LA_T_3354330.flac
#   inflating: selected_train_audio/spoof/LA_T_1788591.flac
#   inflating: selected_train_audio/spoof/LA_T_2541690.flac
#   inflating: selected_train_audio/spoof/LA_T_4630240.flac
#   inflating: selected_train_audio/spoof/LA_T_1057046.flac
#   inflating: selected_train_audio/spoof/LA_T_3479302.flac
#   inflating: selected_train_audio/spoof/LA_T_2413287.flac
#   inflating: selected_train_audio/spoof/LA_T_4647642.flac
#   inflating: selected_train_audio/spoof/LA_T_2895282.flac
#   inflating: selected_train_audio/spoof/LA_T_4815149.flac
#   inflating: selected_train_audio/spoof/LA_T_1870365.flac
#   inflating: selected_train_audio/spoof/LA_T_1571245.flac
#   inflating: selected_train_audio/spoof/LA_T_4626416.flac
#   inflating: selected_train_audio/spoof/LA_T_4288662.flac
#   inflating: selected_train_audio/spoof/LA_T_2726869.flac
#   inflating: selected_train_audio/spoof/LA_T_3893572.flac
#   inflating: selected_train_audio/spoof/LA_T_1439073.flac
#   inflating: selected_train_audio/spoof/LA_T_3778920.flac
#   inflating: selected_train_audio/spoof/LA_T_3497336.flac
#   inflating: selected_train_audio/spoof/LA_T_2577658.flac
#   inflating: selected_train_audio/spoof/LA_T_2762276.flac
#   inflating: selected_train_audio/spoof/LA_T_1743658.flac
#   inflating: selected_train_audio/spoof/LA_T_3501915.flac
#   inflating: selected_train_audio/spoof/LA_T_3817314.flac
#   inflating: selected_train_audio/spoof/LA_T_1306139.flac
#   inflating: selected_train_audio/spoof/LA_T_3575657.flac
#   inflating: selected_train_audio/spoof/LA_T_1657411.flac
#   inflating: selected_train_audio/spoof/LA_T_4310953.flac
#   inflating: selected_train_audio/spoof/LA_T_2870726.flac
#   inflating: selected_train_audio/spoof/LA_T_1306887.flac
#   inflating: selected_train_audio/spoof/LA_T_2025216.flac
#   inflating: selected_train_audio/spoof/LA_T_4106184.flac
#   inflating: selected_train_audio/spoof/LA_T_1253735.flac
#   inflating: selected_train_audio/spoof/LA_T_1367981.flac
#   inflating: selected_train_audio/spoof/LA_T_4286968.flac
#   inflating: selected_train_audio/spoof/LA_T_1809492.flac
#   inflating: selected_train_audio/spoof/LA_T_3024589.flac
#   inflating: selected_train_audio/spoof/LA_T_1059937.flac
#   inflating: selected_train_audio/spoof/LA_T_3428167.flac
#   inflating: selected_train_audio/spoof/LA_T_4284600.flac
#   inflating: selected_train_audio/spoof/LA_T_3704463.flac
#   inflating: selected_train_audio/spoof/LA_T_2178754.flac
#   inflating: selected_train_audio/spoof/LA_T_4364091.flac
#   inflating: selected_train_audio/spoof/LA_T_2977629.flac
#   inflating: selected_train_audio/spoof/LA_T_1639049.flac
#   inflating: selected_train_audio/spoof/LA_T_3296816.flac
#   inflating: selected_train_audio/spoof/LA_T_4446645.flac
#   inflating: selected_train_audio/spoof/LA_T_3512350.flac
#   inflating: selected_train_audio/spoof/LA_T_1684695.flac
#   inflating: selected_train_audio/spoof/LA_T_2915250.flac
#   inflating: selected_train_audio/spoof/LA_T_1373588.flac
#   inflating: selected_train_audio/spoof/LA_T_2942952.flac
#   inflating: selected_train_audio/spoof/LA_T_3902456.flac
#   inflating: selected_train_audio/spoof/LA_T_3449001.flac
#   inflating: selected_train_audio/spoof/LA_T_3174747.flac
#   inflating: selected_train_audio/spoof/LA_T_4271888.flac
#   inflating: selected_train_audio/spoof/LA_T_4213352.flac
#   inflating: selected_train_audio/spoof/LA_T_4551441.flac
#   inflating: selected_train_audio/spoof/LA_T_4505325.flac
#   inflating: selected_train_audio/spoof/LA_T_4882478.flac
#   inflating: selected_train_audio/spoof/LA_T_4207260.flac
#   inflating: selected_train_audio/spoof/LA_T_1718498.flac
#   inflating: selected_train_audio/spoof/LA_T_2335971.flac
#   inflating: selected_train_audio/spoof/LA_T_2793031.flac
#   inflating: selected_train_audio/spoof/LA_T_4341398.flac
#   inflating: selected_train_audio/spoof/LA_T_4865415.flac
#   inflating: selected_train_audio/spoof/LA_T_2056730.flac
#   inflating: selected_train_audio/spoof/LA_T_2117461.flac
#   inflating: selected_train_audio/spoof/LA_T_1388125.flac
#   inflating: selected_train_audio/spoof/LA_T_1107106.flac
#   inflating: selected_train_audio/spoof/LA_T_3455354.flac
#   inflating: selected_train_audio/spoof/LA_T_3381321.flac
#   inflating: selected_train_audio/spoof/LA_T_3610140.flac
#   inflating: selected_train_audio/spoof/LA_T_2485852.flac
#   inflating: selected_train_audio/spoof/LA_T_2494650.flac
#   inflating: selected_train_audio/spoof/LA_T_4466470.flac
#   inflating: selected_train_audio/spoof/LA_T_4645918.flac
#   inflating: selected_train_audio/spoof/LA_T_1468959.flac
#   inflating: selected_train_audio/spoof/LA_T_1183321.flac
#   inflating: selected_train_audio/spoof/LA_T_2688631.flac
#   inflating: selected_train_audio/spoof/LA_T_3429765.flac
#   inflating: selected_train_audio/spoof/LA_T_3627862.flac
#   inflating: selected_train_audio/spoof/LA_T_4310768.flac
#   inflating: selected_train_audio/spoof/LA_T_2832247.flac
#   inflating: selected_train_audio/spoof/LA_T_1380546.flac
#   inflating: selected_train_audio/spoof/LA_T_1613934.flac
#   inflating: selected_train_audio/spoof/LA_T_4461316.flac
#   inflating: selected_train_audio/spoof/LA_T_2280484.flac
#   inflating: selected_train_audio/spoof/LA_T_1462183.flac
#   inflating: selected_train_audio/spoof/LA_T_3458159.flac
#   inflating: selected_train_audio/spoof/LA_T_2194809.flac
#   inflating: selected_train_audio/spoof/LA_T_2904574.flac
#   inflating: selected_train_audio/spoof/LA_T_2312030.flac
#   inflating: selected_train_audio/spoof/LA_T_2433481.flac
#   inflating: selected_train_audio/spoof/LA_T_1722998.flac
#   inflating: selected_train_audio/spoof/LA_T_4533755.flac
#   inflating: selected_train_audio/spoof/LA_T_2010831.flac
#   inflating: selected_train_audio/spoof/LA_T_2316984.flac
#   inflating: selected_train_audio/spoof/LA_T_4546214.flac
#   inflating: selected_train_audio/spoof/LA_T_4168258.flac
#   inflating: selected_train_audio/spoof/LA_T_2951940.flac
#   inflating: selected_train_audio/spoof/LA_T_3652205.flac
#   inflating: selected_train_audio/spoof/LA_T_4119518.flac
#   inflating: selected_train_audio/spoof/LA_T_4898738.flac
#   inflating: selected_train_audio/spoof/LA_T_2779861.flac
#   inflating: selected_train_audio/spoof/LA_T_2018648.flac
#   inflating: selected_train_audio/spoof/LA_T_1072646.flac
#   inflating: selected_train_audio/spoof/LA_T_4260731.flac
#   inflating: selected_train_audio/spoof/LA_T_1626908.flac
#   inflating: selected_train_audio/spoof/LA_T_2886755.flac
#   inflating: selected_train_audio/spoof/LA_T_2992868.flac
#   inflating: selected_train_audio/spoof/LA_T_4368710.flac
#   inflating: selected_train_audio/spoof/LA_T_1398203.flac
#   inflating: selected_train_audio/spoof/LA_T_1318171.flac
#   inflating: selected_train_audio/spoof/LA_T_3193625.flac
#   inflating: selected_train_audio/spoof/LA_T_4253410.flac
#   inflating: selected_train_audio/spoof/LA_T_3411067.flac
#   inflating: selected_train_audio/spoof/LA_T_1402948.flac
#   inflating: selected_train_audio/spoof/LA_T_2088659.flac
#   inflating: selected_train_audio/spoof/LA_T_2909840.flac
#   inflating: selected_train_audio/spoof/LA_T_4283411.flac
#   inflating: selected_train_audio/spoof/LA_T_1181809.flac
#   inflating: selected_train_audio/spoof/LA_T_1126118.flac
#   inflating: selected_train_audio/spoof/LA_T_2928324.flac
#   inflating: selected_train_audio/spoof/LA_T_2561222.flac
#   inflating: selected_train_audio/spoof/LA_T_1268178.flac
#   inflating: selected_train_audio/spoof/LA_T_1571334.flac
#   inflating: selected_train_audio/spoof/LA_T_1107670.flac
#   inflating: selected_train_audio/spoof/LA_T_1531403.flac
#   inflating: selected_train_audio/spoof/LA_T_1217503.flac
#   inflating: selected_train_audio/spoof/LA_T_2451883.flac
#   inflating: selected_train_audio/spoof/LA_T_2362815.flac
#   inflating: selected_train_audio/spoof/LA_T_3355141.flac
#   inflating: selected_train_audio/spoof/LA_T_4521219.flac
#   inflating: selected_train_audio/spoof/LA_T_4021398.flac
#   inflating: selected_train_audio/spoof/LA_T_2198931.flac
#   inflating: selected_train_audio/spoof/LA_T_1326284.flac
#   inflating: selected_train_audio/spoof/LA_T_3168679.flac
#   inflating: selected_train_audio/spoof/LA_T_4220511.flac
#   inflating: selected_train_audio/spoof/LA_T_3218771.flac
#   inflating: selected_train_audio/spoof/LA_T_1181838.flac
#   inflating: selected_train_audio/spoof/LA_T_2881097.flac
#   inflating: selected_train_audio/spoof/LA_T_2848975.flac
#   inflating: selected_train_audio/spoof/LA_T_4629766.flac
#   inflating: selected_train_audio/spoof/LA_T_1783348.flac
#   inflating: selected_train_audio/spoof/LA_T_3717905.flac
#   inflating: selected_train_audio/spoof/LA_T_2943567.flac
#   inflating: selected_train_audio/spoof/LA_T_1913937.flac
#   inflating: selected_train_audio/spoof/LA_T_4512972.flac
#   inflating: selected_train_audio/spoof/LA_T_2651172.flac
#   inflating: selected_train_audio/spoof/LA_T_3246637.flac
#   inflating: selected_train_audio/spoof/LA_T_2804616.flac
#   inflating: selected_train_audio/spoof/LA_T_2209315.flac
#   inflating: selected_train_audio/spoof/LA_T_1921782.flac
#   inflating: selected_train_audio/spoof/LA_T_4176606.flac
#   inflating: selected_train_audio/spoof/LA_T_2120698.flac
#   inflating: selected_train_audio/spoof/LA_T_1228949.flac
#   inflating: selected_train_audio/spoof/LA_T_2746059.flac
#   inflating: selected_train_audio/spoof/LA_T_3475233.flac
#   inflating: selected_train_audio/spoof/LA_T_4646104.flac
#   inflating: selected_train_audio/spoof/LA_T_1490411.flac
#   inflating: selected_train_audio/spoof/LA_T_3591691.flac
#   inflating: selected_train_audio/spoof/LA_T_2995069.flac
#   inflating: selected_train_audio/spoof/LA_T_2547865.flac
#   inflating: selected_train_audio/spoof/LA_T_3247293.flac
#   inflating: selected_train_audio/spoof/LA_T_2218829.flac
#   inflating: selected_train_audio/spoof/LA_T_3901526.flac
#   inflating: selected_train_audio/spoof/LA_T_3316421.flac
#   inflating: selected_train_audio/spoof/LA_T_1198582.flac
#   inflating: selected_train_audio/spoof/LA_T_3846998.flac
#   inflating: selected_train_audio/spoof/LA_T_2223118.flac
#   inflating: selected_train_audio/spoof/LA_T_3266513.flac
#   inflating: selected_train_audio/spoof/LA_T_3969800.flac
#   inflating: selected_train_audio/spoof/LA_T_4156985.flac
#   inflating: selected_train_audio/spoof/LA_T_1834224.flac
#   inflating: selected_train_audio/spoof/LA_T_1252180.flac
#   inflating: selected_train_audio/spoof/LA_T_4384628.flac
#   inflating: selected_train_audio/spoof/LA_T_3437102.flac
#   inflating: selected_train_audio/spoof/LA_T_2686960.flac
#   inflating: selected_train_audio/spoof/LA_T_4384905.flac
#   inflating: selected_train_audio/spoof/LA_T_4385363.flac
#   inflating: selected_train_audio/spoof/LA_T_3790142.flac
#   inflating: selected_train_audio/spoof/LA_T_1908349.flac
#   inflating: selected_train_audio/spoof/LA_T_3694961.flac
#   inflating: selected_train_audio/spoof/LA_T_1041400.flac
#   inflating: selected_train_audio/spoof/LA_T_1651382.flac
#   inflating: selected_train_audio/spoof/LA_T_2315297.flac
#   inflating: selected_train_audio/spoof/LA_T_2350573.flac
#   inflating: selected_train_audio/spoof/LA_T_4404378.flac
#   inflating: selected_train_audio/spoof/LA_T_1454280.flac
#   inflating: selected_train_audio/spoof/LA_T_4357712.flac
#   inflating: selected_train_audio/spoof/LA_T_2237991.flac
#   inflating: selected_train_audio/spoof/LA_T_2178643.flac
#   inflating: selected_train_audio/spoof/LA_T_3433376.flac
#   inflating: selected_train_audio/spoof/LA_T_2824055.flac
#   inflating: selected_train_audio/spoof/LA_T_3639058.flac
#   inflating: selected_train_audio/spoof/LA_T_4269798.flac
#   inflating: selected_train_audio/spoof/LA_T_1684265.flac
#   inflating: selected_train_audio/spoof/LA_T_4406315.flac
#   inflating: selected_train_audio/spoof/LA_T_1366523.flac
#   inflating: selected_train_audio/spoof/LA_T_4823295.flac
#   inflating: selected_train_audio/spoof/LA_T_3013589.flac
#   inflating: selected_train_audio/spoof/LA_T_3865731.flac
#   inflating: selected_train_audio/spoof/LA_T_1167616.flac
#   inflating: selected_train_audio/spoof/LA_T_4005477.flac
#   inflating: selected_train_audio/spoof/LA_T_4278106.flac
#   inflating: selected_train_audio/spoof/LA_T_2051069.flac
#   inflating: selected_train_audio/spoof/LA_T_4798067.flac
#   inflating: selected_train_audio/spoof/LA_T_2348705.flac
#   inflating: selected_train_audio/spoof/LA_T_2329123.flac
#   inflating: selected_train_audio/spoof/LA_T_4007213.flac
#   inflating: selected_train_audio/spoof/LA_T_3083258.flac
#   inflating: selected_train_audio/spoof/LA_T_4656333.flac
#   inflating: selected_train_audio/spoof/LA_T_3875533.flac
#   inflating: selected_train_audio/spoof/LA_T_3371366.flac
#   inflating: selected_train_audio/spoof/LA_T_3256127.flac
#   inflating: selected_train_audio/spoof/LA_T_2065463.flac
#   inflating: selected_train_audio/spoof/LA_T_1500881.flac
#   inflating: selected_train_audio/spoof/LA_T_3955687.flac
#   inflating: selected_train_audio/spoof/LA_T_1678695.flac
#   inflating: selected_train_audio/spoof/LA_T_1657386.flac
#   inflating: selected_train_audio/spoof/LA_T_2012479.flac
#   inflating: selected_train_audio/spoof/LA_T_4683062.flac
#   inflating: selected_train_audio/spoof/LA_T_2677591.flac
#   inflating: selected_train_audio/spoof/LA_T_4675650.flac
#   inflating: selected_train_audio/spoof/LA_T_3763444.flac
#   inflating: selected_train_audio/spoof/LA_T_3107062.flac
#   inflating: selected_train_audio/spoof/LA_T_4584882.flac
#   inflating: selected_train_audio/spoof/LA_T_2943270.flac
#   inflating: selected_train_audio/spoof/LA_T_1308573.flac
#   inflating: selected_train_audio/spoof/LA_T_3567053.flac
#   inflating: selected_train_audio/spoof/LA_T_2949940.flac
#   inflating: selected_train_audio/spoof/LA_T_4398219.flac
#   inflating: selected_train_audio/spoof/LA_T_2837490.flac
#   inflating: selected_train_audio/spoof/LA_T_2274071.flac
#   inflating: selected_train_audio/spoof/LA_T_4304590.flac
#   inflating: selected_train_audio/spoof/LA_T_4363089.flac
#   inflating: selected_train_audio/spoof/LA_T_1043044.flac
#   inflating: selected_train_audio/spoof/LA_T_2577853.flac
#   inflating: selected_train_audio/spoof/LA_T_4317473.flac
#   inflating: selected_train_audio/spoof/LA_T_4681207.flac
#   inflating: selected_train_audio/spoof/LA_T_4574602.flac
#   inflating: selected_train_audio/spoof/LA_T_1381320.flac
#   inflating: selected_train_audio/spoof/LA_T_1318191.flac
#   inflating: selected_train_audio/spoof/LA_T_4452626.flac
#   inflating: selected_train_audio/spoof/LA_T_3615583.flac
#   inflating: selected_train_audio/spoof/LA_T_4016192.flac
#   inflating: selected_train_audio/spoof/LA_T_2210210.flac
#   inflating: selected_train_audio/spoof/LA_T_2260085.flac
#   inflating: selected_train_audio/spoof/LA_T_1034356.flac
#   inflating: selected_train_audio/spoof/LA_T_2925801.flac
#   inflating: selected_train_audio/spoof/LA_T_3022880.flac
#   inflating: selected_train_audio/spoof/LA_T_1587253.flac
#   inflating: selected_train_audio/spoof/LA_T_3556028.flac
#   inflating: selected_train_audio/spoof/LA_T_1130893.flac
#   inflating: selected_train_audio/spoof/LA_T_4844490.flac
#   inflating: selected_train_audio/spoof/LA_T_2175663.flac
#   inflating: selected_train_audio/spoof/LA_T_1113931.flac
#   inflating: selected_train_audio/spoof/LA_T_2224917.flac
#   inflating: selected_train_audio/spoof/LA_T_2462718.flac
#   inflating: selected_train_audio/spoof/LA_T_1819324.flac
#   inflating: selected_train_audio/spoof/LA_T_3206239.flac
#   inflating: selected_train_audio/spoof/LA_T_4699112.flac
#   inflating: selected_train_audio/spoof/LA_T_2782227.flac
#   inflating: selected_train_audio/spoof/LA_T_2930955.flac
#   inflating: selected_train_audio/spoof/LA_T_1410503.flac
#   inflating: selected_train_audio/spoof/LA_T_3280870.flac
#   inflating: selected_train_audio/spoof/LA_T_2130469.flac
#   inflating: selected_train_audio/spoof/LA_T_2567772.flac
#   inflating: selected_train_audio/spoof/LA_T_2534926.flac
#   inflating: selected_train_audio/spoof/LA_T_4020059.flac
#   inflating: selected_train_audio/spoof/LA_T_3891046.flac
#   inflating: selected_train_audio/spoof/LA_T_1238076.flac
#   inflating: selected_train_audio/spoof/LA_T_3394890.flac
#   inflating: selected_train_audio/spoof/LA_T_1439422.flac
#   inflating: selected_train_audio/spoof/LA_T_4064823.flac
#   inflating: selected_train_audio/spoof/LA_T_3685206.flac
#   inflating: selected_train_audio/spoof/LA_T_1212117.flac
#   inflating: selected_train_audio/spoof/LA_T_4347902.flac
#   inflating: selected_train_audio/spoof/LA_T_2826802.flac
#   inflating: selected_train_audio/spoof/LA_T_2820654.flac
#   inflating: selected_train_audio/spoof/LA_T_4084029.flac
#   inflating: selected_train_audio/spoof/LA_T_1637236.flac
#   inflating: selected_train_audio/spoof/LA_T_4287737.flac
#   inflating: selected_train_audio/spoof/LA_T_1526500.flac
#   inflating: selected_train_audio/spoof/LA_T_1207779.flac
#   inflating: selected_train_audio/spoof/LA_T_1504883.flac
#   inflating: selected_train_audio/spoof/LA_T_3580594.flac
#   inflating: selected_train_audio/spoof/LA_T_4752207.flac
#   inflating: selected_train_audio/spoof/LA_T_1739464.flac
#   inflating: selected_train_audio/spoof/LA_T_4840741.flac
#   inflating: selected_train_audio/spoof/LA_T_2474243.flac
#   inflating: selected_train_audio/spoof/LA_T_1996478.flac
#   inflating: selected_train_audio/spoof/LA_T_1059324.flac
#   inflating: selected_train_audio/spoof/LA_T_4125923.flac
#   inflating: selected_train_audio/spoof/LA_T_3483017.flac
#   inflating: selected_train_audio/spoof/LA_T_1711083.flac
#   inflating: selected_train_audio/spoof/LA_T_2020059.flac
#   inflating: selected_train_audio/spoof/LA_T_4190963.flac
#   inflating: selected_train_audio/spoof/LA_T_4019101.flac
#   inflating: selected_train_audio/spoof/LA_T_2799727.flac
#   inflating: selected_train_audio/spoof/LA_T_1876433.flac
#   inflating: selected_train_audio/spoof/LA_T_1836954.flac
#   inflating: selected_train_audio/spoof/LA_T_3158803.flac
#   inflating: selected_train_audio/spoof/LA_T_3202119.flac
#   inflating: selected_train_audio/spoof/LA_T_2668874.flac
#   inflating: selected_train_audio/spoof/LA_T_1308578.flac
#   inflating: selected_train_audio/spoof/LA_T_3728467.flac
#   inflating: selected_train_audio/spoof/LA_T_3181660.flac
#   inflating: selected_train_audio/spoof/LA_T_2484285.flac
#   inflating: selected_train_audio/spoof/LA_T_3067843.flac
#   inflating: selected_train_audio/spoof/LA_T_2864834.flac
#   inflating: selected_train_audio/spoof/LA_T_3247339.flac
#   inflating: selected_train_audio/spoof/LA_T_4047113.flac
#   inflating: selected_train_audio/spoof/LA_T_3491056.flac
#   inflating: selected_train_audio/spoof/LA_T_1863019.flac
#   inflating: selected_train_audio/spoof/LA_T_3800128.flac
#   inflating: selected_train_audio/spoof/LA_T_3465339.flac
#   inflating: selected_train_audio/spoof/LA_T_2163520.flac
#   inflating: selected_train_audio/spoof/LA_T_2524756.flac
#   inflating: selected_train_audio/spoof/LA_T_2244820.flac
#   inflating: selected_train_audio/spoof/LA_T_4753459.flac
#   inflating: selected_train_audio/spoof/LA_T_4605672.flac
#   inflating: selected_train_audio/spoof/LA_T_2775081.flac
#   inflating: selected_train_audio/spoof/LA_T_4788656.flac
#   inflating: selected_train_audio/spoof/LA_T_4465139.flac
#   inflating: selected_train_audio/spoof/LA_T_2533771.flac
#   inflating: selected_train_audio/spoof/LA_T_1740849.flac
#   inflating: selected_train_audio/spoof/LA_T_4571977.flac
#   inflating: selected_train_audio/spoof/LA_T_3421188.flac
#   inflating: selected_train_audio/spoof/LA_T_3465206.flac
#   inflating: selected_train_audio/spoof/LA_T_1529797.flac
#   inflating: selected_train_audio/spoof/LA_T_2531529.flac
#   inflating: selected_train_audio/spoof/LA_T_3328430.flac
#   inflating: selected_train_audio/spoof/LA_T_4726653.flac
#   inflating: selected_train_audio/spoof/LA_T_1683184.flac
#   inflating: selected_train_audio/spoof/LA_T_3744266.flac
#   inflating: selected_train_audio/spoof/LA_T_4894778.flac
#   inflating: selected_train_audio/spoof/LA_T_1084255.flac
#   inflating: selected_train_audio/spoof/LA_T_1646130.flac
#   inflating: selected_train_audio/spoof/LA_T_1628509.flac
#   inflating: selected_train_audio/spoof/LA_T_2870485.flac
#   inflating: selected_train_audio/spoof/LA_T_1468802.flac
#   inflating: selected_train_audio/spoof/LA_T_2509031.flac
#   inflating: selected_train_audio/spoof/LA_T_3507539.flac
#   inflating: selected_train_audio/spoof/LA_T_1461872.flac
#   inflating: selected_train_audio/spoof/LA_T_2156280.flac
#   inflating: selected_train_audio/spoof/LA_T_3358436.flac
#   inflating: selected_train_audio/spoof/LA_T_3921670.flac
#   inflating: selected_train_audio/spoof/LA_T_3552476.flac
#   inflating: selected_train_audio/spoof/LA_T_2159415.flac
#   inflating: selected_train_audio/spoof/LA_T_2796852.flac
#   inflating: selected_train_audio/spoof/LA_T_3970268.flac
#   inflating: selected_train_audio/spoof/LA_T_3362198.flac
#   inflating: selected_train_audio/spoof/LA_T_2125043.flac
#   inflating: selected_train_audio/spoof/LA_T_4160527.flac
#   inflating: selected_train_audio/spoof/LA_T_3725258.flac
#   inflating: selected_train_audio/spoof/LA_T_1390747.flac
#   inflating: selected_train_audio/spoof/LA_T_1531506.flac
#   inflating: selected_train_audio/spoof/LA_T_1006715.flac
#   inflating: selected_train_audio/spoof/LA_T_1836518.flac
#   inflating: selected_train_audio/spoof/LA_T_3085342.flac
#   inflating: selected_train_audio/spoof/LA_T_1363700.flac
#   inflating: selected_train_audio/spoof/LA_T_2576091.flac
#   inflating: selected_train_audio/spoof/LA_T_3848280.flac
#   inflating: selected_train_audio/spoof/LA_T_4000361.flac
#   inflating: selected_train_audio/spoof/LA_T_4717070.flac
#   inflating: selected_train_audio/spoof/LA_T_2015463.flac
#   inflating: selected_train_audio/spoof/LA_T_4467080.flac
#   inflating: selected_train_audio/spoof/LA_T_4197468.flac
#   inflating: selected_train_audio/spoof/LA_T_4314776.flac
#   inflating: selected_train_audio/spoof/LA_T_2326183.flac
#   inflating: selected_train_audio/spoof/LA_T_4554808.flac
#   inflating: selected_train_audio/spoof/LA_T_4667002.flac
#   inflating: selected_train_audio/spoof/LA_T_4495473.flac
#   inflating: selected_train_audio/spoof/LA_T_3107580.flac
#   inflating: selected_train_audio/spoof/LA_T_1687775.flac
#   inflating: selected_train_audio/spoof/LA_T_4704382.flac
#   inflating: selected_train_audio/spoof/LA_T_3771447.flac
#   inflating: selected_train_audio/spoof/LA_T_3100698.flac
#   inflating: selected_train_audio/spoof/LA_T_4019568.flac
#   inflating: selected_train_audio/spoof/LA_T_4685609.flac
#   inflating: selected_train_audio/spoof/LA_T_1848099.flac
#   inflating: selected_train_audio/spoof/LA_T_1806261.flac
#   inflating: selected_train_audio/spoof/LA_T_2899278.flac
#   inflating: selected_train_audio/spoof/LA_T_3182996.flac
#   inflating: selected_train_audio/spoof/LA_T_2231672.flac
#   inflating: selected_train_audio/spoof/LA_T_4772983.flac
#   inflating: selected_train_audio/spoof/LA_T_4472122.flac
#   inflating: selected_train_audio/spoof/LA_T_3704769.flac
#   inflating: selected_train_audio/spoof/LA_T_4502257.flac
#   inflating: selected_train_audio/spoof/LA_T_3104814.flac
#   inflating: selected_train_audio/spoof/LA_T_3388375.flac
#   inflating: selected_train_audio/spoof/LA_T_3134909.flac
#   inflating: selected_train_audio/spoof/LA_T_3088653.flac
#   inflating: selected_train_audio/spoof/LA_T_2587075.flac
#   inflating: selected_train_audio/spoof/LA_T_1868826.flac
#   inflating: selected_train_audio/spoof/LA_T_3627398.flac
#   inflating: selected_train_audio/spoof/LA_T_4785031.flac
#   inflating: selected_train_audio/spoof/LA_T_4410160.flac
#   inflating: selected_train_audio/spoof/LA_T_1449747.flac
#   inflating: selected_train_audio/spoof/LA_T_1609049.flac
#   inflating: selected_train_audio/spoof/LA_T_3852468.flac
#   inflating: selected_train_audio/spoof/LA_T_3629600.flac
#   inflating: selected_train_audio/spoof/LA_T_3933288.flac
#   inflating: selected_train_audio/spoof/LA_T_4535334.flac
#   inflating: selected_train_audio/spoof/LA_T_2903409.flac
#   inflating: selected_train_audio/spoof/LA_T_2765353.flac
#   inflating: selected_train_audio/spoof/LA_T_3725606.flac
#   inflating: selected_train_audio/spoof/LA_T_1832373.flac
#   inflating: selected_train_audio/spoof/LA_T_3486374.flac
#   inflating: selected_train_audio/spoof/LA_T_3843398.flac
#   inflating: selected_train_audio/spoof/LA_T_3796700.flac
#   inflating: selected_train_audio/spoof/LA_T_1090807.flac
#   inflating: selected_train_audio/spoof/LA_T_3402567.flac
#   inflating: selected_train_audio/spoof/LA_T_4538383.flac
#   inflating: selected_train_audio/spoof/LA_T_2269511.flac
#   inflating: selected_train_audio/spoof/LA_T_1147556.flac
#   inflating: selected_train_audio/spoof/LA_T_2966801.flac
#   inflating: selected_train_audio/spoof/LA_T_2284050.flac
#   inflating: selected_train_audio/spoof/LA_T_1976045.flac
#   inflating: selected_train_audio/spoof/LA_T_3144890.flac
#   inflating: selected_train_audio/spoof/LA_T_4332444.flac
#   inflating: selected_train_audio/spoof/LA_T_1923646.flac
#   inflating: selected_train_audio/spoof/LA_T_2577284.flac
#   inflating: selected_train_audio/spoof/LA_T_4504323.flac
#   inflating: selected_train_audio/spoof/LA_T_2113016.flac
#   inflating: selected_train_audio/spoof/LA_T_2580311.flac
#   inflating: selected_train_audio/spoof/LA_T_3386033.flac
#   inflating: selected_train_audio/spoof/LA_T_2202599.flac
#   inflating: selected_train_audio/spoof/LA_T_4492237.flac
#   inflating: selected_train_audio/spoof/LA_T_3719601.flac
#   inflating: selected_train_audio/spoof/LA_T_1114442.flac
#   inflating: selected_train_audio/spoof/LA_T_3355545.flac
#   inflating: selected_train_audio/spoof/LA_T_2302867.flac
#   inflating: selected_train_audio/spoof/LA_T_1594781.flac
#   inflating: selected_train_audio/spoof/LA_T_4481438.flac
#   inflating: selected_train_audio/spoof/LA_T_1411943.flac
#   inflating: selected_train_audio/spoof/LA_T_3401061.flac
#   inflating: selected_train_audio/spoof/LA_T_1347970.flac
#   inflating: selected_train_audio/spoof/LA_T_1983641.flac
#   inflating: selected_train_audio/spoof/LA_T_2940045.flac
#   inflating: selected_train_audio/spoof/LA_T_3181565.flac
#   inflating: selected_train_audio/spoof/LA_T_4642426.flac
#   inflating: selected_train_audio/spoof/LA_T_4412351.flac
#   inflating: selected_train_audio/spoof/LA_T_1473188.flac
#   inflating: selected_train_audio/spoof/LA_T_2815642.flac
#   inflating: selected_train_audio/spoof/LA_T_1049212.flac
#   inflating: selected_train_audio/spoof/LA_T_1663309.flac
#   inflating: selected_train_audio/spoof/LA_T_2804261.flac
#   inflating: selected_train_audio/spoof/LA_T_1485648.flac
#   inflating: selected_train_audio/spoof/LA_T_3915614.flac
#   inflating: selected_train_audio/spoof/LA_T_2405515.flac
#   inflating: selected_train_audio/spoof/LA_T_4775357.flac
#   inflating: selected_train_audio/spoof/LA_T_3654402.flac
#   inflating: selected_train_audio/spoof/LA_T_1408836.flac
#   inflating: selected_train_audio/spoof/LA_T_2689197.flac
#   inflating: selected_train_audio/spoof/LA_T_3901504.flac
#   inflating: selected_train_audio/spoof/LA_T_4646490.flac
#   inflating: selected_train_audio/spoof/LA_T_4445166.flac
#   inflating: selected_train_audio/spoof/LA_T_1453903.flac
#   inflating: selected_train_audio/spoof/LA_T_3939074.flac
#   inflating: selected_train_audio/spoof/LA_T_1760536.flac
#   inflating: selected_train_audio/spoof/LA_T_4558205.flac
#   inflating: selected_train_audio/spoof/LA_T_4105819.flac
#   inflating: selected_train_audio/spoof/LA_T_2732387.flac
#   inflating: selected_train_audio/spoof/LA_T_1108824.flac
#   inflating: selected_train_audio/spoof/LA_T_2449868.flac
#   inflating: selected_train_audio/spoof/LA_T_4468815.flac
#   inflating: selected_train_audio/spoof/LA_T_4042142.flac
#   inflating: selected_train_audio/spoof/LA_T_4470128.flac
#   inflating: selected_train_audio/spoof/LA_T_2434059.flac
#   inflating: selected_train_audio/spoof/LA_T_4080351.flac
#   inflating: selected_train_audio/spoof/LA_T_1365730.flac
#   inflating: selected_train_audio/spoof/LA_T_3917204.flac
#   inflating: selected_train_audio/spoof/LA_T_4667722.flac
#   inflating: selected_train_audio/spoof/LA_T_4198324.flac
#   inflating: selected_train_audio/spoof/LA_T_1310102.flac
#   inflating: selected_train_audio/spoof/LA_T_3618704.flac
#   inflating: selected_train_audio/spoof/LA_T_3461309.flac
#   inflating: selected_train_audio/spoof/LA_T_2732289.flac
#   inflating: selected_train_audio/spoof/LA_T_1305570.flac
#   inflating: selected_train_audio/spoof/LA_T_3669867.flac
#   inflating: selected_train_audio/spoof/LA_T_3153307.flac
#   inflating: selected_train_audio/spoof/LA_T_4801670.flac
#   inflating: selected_train_audio/spoof/LA_T_1078877.flac
#   inflating: selected_train_audio/spoof/LA_T_2199641.flac
#   inflating: selected_train_audio/spoof/LA_T_4496571.flac
#   inflating: selected_train_audio/spoof/LA_T_1100207.flac
#   inflating: selected_train_audio/spoof/LA_T_4755807.flac
#   inflating: selected_train_audio/spoof/LA_T_1589223.flac
#   inflating: selected_train_audio/spoof/LA_T_4609515.flac
#   inflating: selected_train_audio/spoof/LA_T_2690574.flac
#   inflating: selected_train_audio/spoof/LA_T_2929732.flac
#   inflating: selected_train_audio/spoof/LA_T_3629702.flac
#   inflating: selected_train_audio/spoof/LA_T_3247204.flac
#   inflating: selected_train_audio/spoof/LA_T_3861578.flac
#   inflating: selected_train_audio/spoof/LA_T_1777438.flac
#   inflating: selected_train_audio/spoof/LA_T_3021659.flac
#   inflating: selected_train_audio/spoof/LA_T_2641578.flac
#   inflating: selected_train_audio/spoof/LA_T_2048434.flac
#   inflating: selected_train_audio/spoof/LA_T_3384152.flac
#   inflating: selected_train_audio/spoof/LA_T_1211828.flac
#   inflating: selected_train_audio/spoof/LA_T_2017275.flac
#   inflating: selected_train_audio/spoof/LA_T_1663364.flac
#   inflating: selected_train_audio/spoof/LA_T_4072105.flac
#   inflating: selected_train_audio/spoof/LA_T_4704254.flac
#   inflating: selected_train_audio/spoof/LA_T_3682623.flac
#   inflating: selected_train_audio/spoof/LA_T_1689079.flac
# ...
#   inflating: selected_train_audio/spoof/LA_T_1776240.flac
#   inflating: selected_train_audio/spoof/LA_T_2134162.flac
#   inflating: selected_train_audio/spoof/LA_T_2687543.flac
#   inflating: selected_train_audio/spoof/LA_T_2629834.flac
#   inflating: selected_train_audio/spoof/LA_T_2742511.flac
#   inflating: selected_train_audio/spoof/LA_T_3330210.flac
#   inflating: selected_train_audio/spoof/LA_T_1981719.flac
#   inflating: selected_train_audio/spoof/LA_T_4567973.flac
#   inflating: selected_train_audio/spoof/LA_T_3500965.flac
#   inflating: selected_train_audio/spoof/LA_T_1342195.flac
#   inflating: selected_train_audio/spoof/LA_T_2190633.flac
#   inflating: selected_train_audio/spoof/LA_T_2057403.flac
#   inflating: selected_train_audio/spoof/LA_T_4896995.flac
#   inflating: selected_train_audio/spoof/LA_T_2834141.flac
#   inflating: selected_train_audio/spoof/LA_T_3995124.flac
#   inflating: selected_train_audio/spoof/LA_T_3245402.flac
#   inflating: selected_train_audio/spoof/LA_T_4794903.flac
#   inflating: selected_train_audio/spoof/LA_T_2735137.flac
#   inflating: selected_train_audio/spoof/LA_T_4844842.flac
#   inflating: selected_train_audio/spoof/LA_T_4588729.flac
#   inflating: selected_train_audio/spoof/LA_T_4596799.flac
#   inflating: selected_train_audio/spoof/LA_T_3153711.flac
#   inflating: selected_train_audio/spoof/LA_T_2236481.flac
#   inflating: selected_train_audio/spoof/LA_T_2906588.flac
#   inflating: selected_train_audio/spoof/LA_T_3385155.flac
#   inflating: selected_train_audio/spoof/LA_T_3359462.flac
#   inflating: selected_train_audio/spoof/LA_T_4355205.flac
#   inflating: selected_train_audio/spoof/LA_T_2866318.flac
#   inflating: selected_train_audio/spoof/LA_T_1965565.flac
#   inflating: selected_train_audio/spoof/LA_T_3046931.flac
#   inflating: selected_train_audio/spoof/LA_T_2862607.flac
#   inflating: selected_train_audio/spoof/LA_T_3501683.flac
#   inflating: selected_train_audio/spoof/LA_T_4765217.flac
#   inflating: selected_train_audio/spoof/LA_T_3189344.flac
#   inflating: selected_train_audio/spoof/LA_T_4428537.flac
#   inflating: selected_train_audio/spoof/LA_T_1085866.flac
#   inflating: selected_train_audio/spoof/LA_T_2000338.flac
#   inflating: selected_train_audio/spoof/LA_T_2800339.flac
#   inflating: selected_train_audio/spoof/LA_T_1923827.flac
#   inflating: selected_train_audio/spoof/LA_T_2598760.flac
#   inflating: selected_train_audio/spoof/LA_T_3547895.flac
#   inflating: selected_train_audio/spoof/LA_T_4875691.flac
#   inflating: selected_train_audio/spoof/LA_T_3144147.flac
#   inflating: selected_train_audio/spoof/LA_T_1281792.flac
#   inflating: selected_train_audio/spoof/LA_T_1489610.flac
#   inflating: selected_train_audio/spoof/LA_T_1749419.flac
#   inflating: selected_train_audio/spoof/LA_T_4012970.flac
#   inflating: selected_train_audio/spoof/LA_T_2612047.flac
#   inflating: selected_train_audio/spoof/LA_T_2809406.flac
#   inflating: selected_train_audio/spoof/LA_T_3416553.flac
#   inflating: selected_train_audio/spoof/LA_T_1549614.flac
#   inflating: selected_train_audio/spoof/LA_T_3224180.flac
#   inflating: selected_train_audio/spoof/LA_T_4495379.flac
#   inflating: selected_train_audio/spoof/LA_T_1858254.flac
#   inflating: selected_train_audio/spoof/LA_T_1715305.flac
#   inflating: selected_train_audio/spoof/LA_T_2117042.flac
#   inflating: selected_train_audio/spoof/LA_T_2440823.flac
#   inflating: selected_train_audio/spoof/LA_T_1088332.flac
#   inflating: selected_train_audio/spoof/LA_T_1178793.flac
#   inflating: selected_train_audio/spoof/LA_T_4461420.flac
#   inflating: selected_train_audio/spoof/LA_T_2172882.flac
#   inflating: selected_train_audio/spoof/LA_T_3430134.flac
#   inflating: selected_train_audio/spoof/LA_T_2815432.flac
#   inflating: selected_train_audio/spoof/LA_T_2723989.flac
#   inflating: selected_train_audio/spoof/LA_T_1289777.flac
#   inflating: selected_train_audio/spoof/LA_T_2136769.flac
#   inflating: selected_train_audio/spoof/LA_T_3636602.flac
#   inflating: selected_train_audio/spoof/LA_T_1493479.flac
#   inflating: selected_train_audio/spoof/LA_T_3381376.flac
#   inflating: selected_train_audio/spoof/LA_T_2461324.flac
#   inflating: selected_train_audio/spoof/LA_T_3588595.flac
#   inflating: selected_train_audio/spoof/LA_T_2758383.flac
#   inflating: selected_train_audio/spoof/LA_T_4806532.flac
#   inflating: selected_train_audio/spoof/LA_T_4690291.flac
#   inflating: selected_train_audio/spoof/LA_T_1513207.flac
#   inflating: selected_train_audio/spoof/LA_T_4096121.flac
#   inflating: selected_train_audio/spoof/LA_T_1663969.flac
#   inflating: selected_train_audio/spoof/LA_T_2178403.flac
#   inflating: selected_train_audio/spoof/LA_T_3925071.flac
#   inflating: selected_train_audio/spoof/LA_T_2067797.flac
#   inflating: selected_train_audio/spoof/LA_T_2739300.flac
#   inflating: selected_train_audio/spoof/LA_T_4306387.flac
#   inflating: selected_train_audio/spoof/LA_T_1201202.flac
#   inflating: selected_train_audio/spoof/LA_T_2852816.flac
#   inflating: selected_train_audio/spoof/LA_T_2577245.flac
#   inflating: selected_train_audio/spoof/LA_T_4409808.flac
#   inflating: selected_train_audio/spoof/LA_T_2713424.flac
#   inflating: selected_train_audio/spoof/LA_T_3632473.flac
#   inflating: selected_train_audio/spoof/LA_T_1984466.flac
#   inflating: selected_train_audio/spoof/LA_T_1892752.flac
#   inflating: selected_train_audio/spoof/LA_T_1841638.flac
#   inflating: selected_train_audio/spoof/LA_T_1299456.flac
#   inflating: selected_train_audio/spoof/LA_T_2228293.flac
#   inflating: selected_train_audio/spoof/LA_T_3073179.flac
#   inflating: selected_train_audio/spoof/LA_T_2349426.flac
#   inflating: selected_train_audio/spoof/LA_T_4654339.flac
#   inflating: selected_train_audio/spoof/LA_T_1839443.flac
#   inflating: selected_train_audio/spoof/LA_T_4895261.flac
#   inflating: selected_train_audio/spoof/LA_T_4036657.flac
#   inflating: selected_train_audio/spoof/LA_T_4435697.flac
#   inflating: selected_train_audio/spoof/LA_T_1693372.flac
#   inflating: selected_train_audio/spoof/LA_T_4036889.flac
#   inflating: selected_train_audio/spoof/LA_T_4906896.flac
#   inflating: selected_train_audio/spoof/LA_T_1305019.flac
#   inflating: selected_train_audio/spoof/LA_T_3339131.flac
#   inflating: selected_train_audio/spoof/LA_T_2313312.flac
#   inflating: selected_train_audio/spoof/LA_T_3056663.flac
#   inflating: selected_train_audio/spoof/LA_T_4787702.flac
#   inflating: selected_train_audio/spoof/LA_T_2199715.flac
#   inflating: selected_train_audio/spoof/LA_T_3856798.flac
#   inflating: selected_train_audio/spoof/LA_T_3445412.flac
#   inflating: selected_train_audio/spoof/LA_T_3593681.flac
#   inflating: selected_train_audio/spoof/LA_T_2337477.flac
#   inflating: selected_train_audio/spoof/LA_T_1719449.flac
#   inflating: selected_train_audio/spoof/LA_T_4651429.flac
#   inflating: selected_train_audio/spoof/LA_T_3944680.flac
#   inflating: selected_train_audio/spoof/LA_T_4278888.flac
#   inflating: selected_train_audio/spoof/LA_T_3752351.flac
#   inflating: selected_train_audio/spoof/LA_T_1090341.flac
#   inflating: selected_train_audio/spoof/LA_T_1134909.flac
#   inflating: selected_train_audio/spoof/LA_T_3343346.flac
#   inflating: selected_train_audio/spoof/LA_T_3104807.flac
#   inflating: selected_train_audio/spoof/LA_T_3303557.flac
#   inflating: selected_train_audio/spoof/LA_T_1713437.flac
#   inflating: selected_train_audio/spoof/LA_T_3286829.flac
#   inflating: selected_train_audio/spoof/LA_T_4408264.flac
#   inflating: selected_train_audio/spoof/LA_T_3138805.flac
#   inflating: selected_train_audio/spoof/LA_T_3074974.flac
#   inflating: selected_train_audio/spoof/LA_T_1350153.flac
#   inflating: selected_train_audio/spoof/LA_T_3609381.flac
#   inflating: selected_train_audio/spoof/LA_T_3977258.flac
#   inflating: selected_train_audio/spoof/LA_T_4410447.flac
#   inflating: selected_train_audio/spoof/LA_T_4284812.flac
#   inflating: selected_train_audio/spoof/LA_T_2529002.flac
#   inflating: selected_train_audio/spoof/LA_T_1544872.flac
#   inflating: selected_train_audio/spoof/LA_T_1875824.flac
#   inflating: selected_train_audio/spoof/LA_T_2988649.flac
#   inflating: selected_train_audio/spoof/LA_T_1057453.flac
#   inflating: selected_train_audio/spoof/LA_T_1359888.flac
#   inflating: selected_train_audio/spoof/LA_T_3519874.flac
#   inflating: selected_train_audio/spoof/LA_T_1466757.flac
#   inflating: selected_train_audio/spoof/LA_T_4094522.flac
#   inflating: selected_train_audio/spoof/LA_T_1286194.flac
#   inflating: selected_train_audio/spoof/LA_T_4222487.flac
#   inflating: selected_train_audio/spoof/LA_T_4430008.flac
#   inflating: selected_train_audio/spoof/LA_T_2789904.flac
#   inflating: selected_train_audio/spoof/LA_T_4387296.flac
#   inflating: selected_train_audio/spoof/LA_T_2799664.flac
#   inflating: selected_train_audio/spoof/LA_T_3988633.flac
#   inflating: selected_train_audio/spoof/LA_T_4896454.flac
#   inflating: selected_train_audio/spoof/LA_T_4291421.flac
#   inflating: selected_train_audio/spoof/LA_T_1901466.flac
#   inflating: selected_train_audio/spoof/LA_T_1423356.flac
#   inflating: selected_train_audio/spoof/LA_T_3013316.flac
#   inflating: selected_train_audio/spoof/LA_T_2826801.flac
#   inflating: selected_train_audio/spoof/LA_T_2802826.flac
#   inflating: selected_train_audio/spoof/LA_T_3247954.flac
#   inflating: selected_train_audio/spoof/LA_T_1790160.flac
#   inflating: selected_train_audio/spoof/LA_T_4292622.flac
#   inflating: selected_train_audio/spoof/LA_T_4456435.flac
#   inflating: selected_train_audio/spoof/LA_T_1278318.flac
#   inflating: selected_train_audio/spoof/LA_T_3690861.flac
#   inflating: selected_train_audio/spoof/LA_T_2394242.flac
#   inflating: selected_train_audio/spoof/LA_T_4437639.flac
#   inflating: selected_train_audio/spoof/LA_T_4570364.flac
#   inflating: selected_train_audio/spoof/LA_T_3349877.flac
#   inflating: selected_train_audio/spoof/LA_T_3890505.flac
#   inflating: selected_train_audio/spoof/LA_T_2356929.flac
#   inflating: selected_train_audio/spoof/LA_T_1769085.flac
#   inflating: selected_train_audio/spoof/LA_T_1053692.flac
#   inflating: selected_train_audio/spoof/LA_T_4535360.flac
#   inflating: selected_train_audio/spoof/LA_T_4100702.flac
#   inflating: selected_train_audio/spoof/LA_T_1306033.flac
#   inflating: selected_train_audio/spoof/LA_T_4177986.flac
#   inflating: selected_train_audio/spoof/LA_T_2005477.flac
#   inflating: selected_train_audio/spoof/LA_T_1167878.flac
#   inflating: selected_train_audio/spoof/LA_T_4497405.flac
#   inflating: selected_train_audio/spoof/LA_T_4314935.flac
#   inflating: selected_train_audio/spoof/LA_T_3129565.flac
#   inflating: selected_train_audio/spoof/LA_T_3081795.flac
#   inflating: selected_train_audio/spoof/LA_T_3909811.flac
#   inflating: selected_train_audio/spoof/LA_T_4322814.flac
#   inflating: selected_train_audio/spoof/LA_T_3307036.flac
#   inflating: selected_train_audio/spoof/LA_T_1998626.flac
#   inflating: selected_train_audio/spoof/LA_T_1872062.flac
#   inflating: selected_train_audio/spoof/LA_T_3570062.flac
#   inflating: selected_train_audio/spoof/LA_T_3403166.flac
#   inflating: selected_train_audio/spoof/LA_T_3209106.flac
#   inflating: selected_train_audio/spoof/LA_T_1533635.flac
#   inflating: selected_train_audio/spoof/LA_T_4020317.flac
#   inflating: selected_train_audio/spoof/LA_T_1173561.flac
#   inflating: selected_train_audio/spoof/LA_T_2614679.flac
#   inflating: selected_train_audio/spoof/LA_T_2365100.flac
#   inflating: selected_train_audio/spoof/LA_T_1575776.flac
#   inflating: selected_train_audio/spoof/LA_T_4332420.flac
#   inflating: selected_train_audio/spoof/LA_T_2035692.flac
#   inflating: selected_train_audio/spoof/LA_T_4702763.flac
#   inflating: selected_train_audio/spoof/LA_T_1726725.flac
#   inflating: selected_train_audio/spoof/LA_T_2402766.flac
#   inflating: selected_train_audio/spoof/LA_T_2788477.flac
#   inflating: selected_train_audio/spoof/LA_T_1346935.flac
#   inflating: selected_train_audio/spoof/LA_T_4233110.flac
#   inflating: selected_train_audio/spoof/LA_T_2759482.flac
#   inflating: selected_train_audio/spoof/LA_T_3496060.flac
#   inflating: selected_train_audio/spoof/LA_T_4087781.flac
#   inflating: selected_train_audio/spoof/LA_T_1808196.flac
#   inflating: selected_train_audio/spoof/LA_T_1582558.flac
#   inflating: selected_train_audio/spoof/LA_T_3202143.flac
#   inflating: selected_train_audio/spoof/LA_T_3383353.flac
#   inflating: selected_train_audio/spoof/LA_T_4460111.flac
#   inflating: selected_train_audio/spoof/LA_T_1269759.flac
#   inflating: selected_train_audio/spoof/LA_T_2455137.flac
#   inflating: selected_train_audio/spoof/LA_T_3532384.flac
#   inflating: selected_train_audio/spoof/LA_T_2317460.flac
#   inflating: selected_train_audio/spoof/LA_T_4280334.flac
#   inflating: selected_train_audio/spoof/LA_T_1729928.flac
#   inflating: selected_train_audio/spoof/LA_T_2672083.flac
#   inflating: selected_train_audio/spoof/LA_T_3807209.flac
#   inflating: selected_train_audio/spoof/LA_T_1524989.flac
#   inflating: selected_train_audio/spoof/LA_T_4426576.flac
#   inflating: selected_train_audio/spoof/LA_T_1867363.flac
#   inflating: selected_train_audio/spoof/LA_T_3546547.flac
#   inflating: selected_train_audio/spoof/LA_T_2406504.flac
#   inflating: selected_train_audio/spoof/LA_T_4868773.flac
#   inflating: selected_train_audio/spoof/LA_T_3130884.flac
#   inflating: selected_train_audio/spoof/LA_T_1583122.flac
#   inflating: selected_train_audio/spoof/LA_T_1393789.flac
#   inflating: selected_train_audio/spoof/LA_T_4597336.flac
#   inflating: selected_train_audio/spoof/LA_T_2960062.flac
#   inflating: selected_train_audio/spoof/LA_T_1682479.flac
#   inflating: selected_train_audio/spoof/LA_T_1635736.flac
#   inflating: selected_train_audio/spoof/LA_T_3366696.flac
#   inflating: selected_train_audio/spoof/LA_T_1730258.flac
#   inflating: selected_train_audio/spoof/LA_T_2031834.flac
#   inflating: selected_train_audio/spoof/LA_T_1039538.flac
#   inflating: selected_train_audio/spoof/LA_T_3458064.flac
#   inflating: selected_train_audio/spoof/LA_T_2172724.flac
#   inflating: selected_train_audio/spoof/LA_T_1643894.flac
#   inflating: selected_train_audio/spoof/LA_T_4562769.flac
#   inflating: selected_train_audio/spoof/LA_T_4689668.flac
#   inflating: selected_train_audio/spoof/LA_T_2995049.flac
#   inflating: selected_train_audio/spoof/LA_T_2166656.flac
#   inflating: selected_train_audio/spoof/LA_T_4874953.flac
#   inflating: selected_train_audio/spoof/LA_T_1359098.flac
#   inflating: selected_train_audio/spoof/LA_T_4067230.flac
#   inflating: selected_train_audio/spoof/LA_T_4823781.flac
#   inflating: selected_train_audio/spoof/LA_T_2520610.flac
#   inflating: selected_train_audio/spoof/LA_T_4892690.flac
#   inflating: selected_train_audio/spoof/LA_T_2929394.flac
#   inflating: selected_train_audio/spoof/LA_T_2018143.flac
#   inflating: selected_train_audio/spoof/LA_T_3017055.flac
#   inflating: selected_train_audio/spoof/LA_T_3571541.flac
#   inflating: selected_train_audio/spoof/LA_T_1278860.flac
#   inflating: selected_train_audio/spoof/LA_T_2764583.flac
#   inflating: selected_train_audio/spoof/LA_T_4878362.flac
#   inflating: selected_train_audio/spoof/LA_T_3843316.flac
#   inflating: selected_train_audio/spoof/LA_T_4557069.flac
#   inflating: selected_train_audio/spoof/LA_T_2233888.flac
#   inflating: selected_train_audio/spoof/LA_T_2807969.flac
#   inflating: selected_train_audio/spoof/LA_T_2971972.flac
#   inflating: selected_train_audio/spoof/LA_T_2637031.flac
#   inflating: selected_train_audio/spoof/LA_T_3519821.flac
#   inflating: selected_train_audio/spoof/LA_T_3633528.flac
#   inflating: selected_train_audio/spoof/LA_T_2784840.flac
#   inflating: selected_train_audio/spoof/LA_T_3816200.flac
#   inflating: selected_train_audio/spoof/LA_T_2243717.flac

# %%
# Standard library imports
import os
import random
from tqdm import tqdm

# Third-party imports
import torch
import torch.nn as nn
import torchaudio
import pandas as pd
from torch.utils.data import DataLoader, Dataset
from transformers import Wav2Vec2Processor, WhisperFeatureExtractor
import matplotlib.pyplot as plt

import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from torch.utils.tensorboard import SummaryWriter

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# ## Data Visualization
#
# > In the realm of deepfake audio detection, various audio features are instrumental in distinguishing between authentic and synthetic recordings. Among these, spectrograms, Mel spectrograms, and chroma features are particularly noteworthy.
#
# ### Spectograms
# * Spectrograms provide a visual representation of an audio signal's frequency spectrum over time, capturing both temporal and spectral information. This dual representation is advantageous for detecting anomalies indicative of deepfake audio. For instance, certain synthesis methods may introduce artifacts or inconsistencies in the frequency domain, which become apparent when analyzing spectrograms. By examining these visual patterns, researchers can identify irregularities that suggest audio manipulation.
# ARXIV
#
# ## Mel Spectograms
# * Mel spectrograms are a variant of spectrograms that map frequencies onto the Mel scale, aligning more closely with human auditory perception. This perceptually motivated scaling emphasizes frequencies to which the human ear is more sensitive, thereby enhancing the detection of subtle artifacts introduced by deepfake generation techniques. Studies have demonstrated that Mel spectrograms, when used as input features for convolutional neural networks, improve the accuracy of deepfake audio detection systems.
# ICTACT JOURNALS
#
# ## Chroma Features
# * Chroma features capture the energy distribution across the twelve distinct pitch classes of the musical octave, effectively summarizing harmonic content. In the context of deepfake detection, chroma features are valuable for identifying inconsistencies in the harmonic structure of audio signals. Synthetic audio may exhibit unnatural harmonic patterns or deviations in pitch class distributions, which chroma analysis can reveal. Incorporating chroma features into detection frameworks has been shown to enhance the robustness of classifiers against various types of audio forgeries.
# IEEE XPLORE
#
# > Collectively, these features—spectrograms, Mel spectrograms, and chroma features—serve as critical tools in the detection of deepfake audio. By providing comprehensive insights into the spectral, perceptual, and harmonic characteristics of audio signals, they enable more effective identification of synthetic content.

# %%
import os
import torch
import torchaudio
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Audio

def visualize_audio_features(audio_file):
    """
    Visualizes different audio representations: waveform, spectrogram, Mel spectrogram, and chroma feature.

    Args:
        audio_file (str): Path to a specific audio file (.flac or any other format supported by torchaudio).
    """
    # Load the audio file
    audio, sample_rate = torchaudio.load(audio_file)

    # Ensure audio is in mono for consistent visualization
    if audio.shape[0] > 1:
        audio = audio.mean(dim=0)

    # Normalize audio for better visualization
    audio = audio / torch.max(torch.abs(audio))
    waveform_audio = audio.squeeze().numpy()

    # Display the original waveform
    plt.figure(figsize=(15, 10))
    plt.subplot(2, 2, 1)
    plt.plot(waveform_audio, color='red')
    plt.title("Waveform")
    plt.xlabel("Samples")
    plt.ylabel("Amplitude")

    # Compute and display the spectrogram
    spectrogram = torchaudio.transforms.Spectrogram()(audio)
    plt.subplot(2, 2, 2)
    plt.imshow(spectrogram.log2().squeeze().detach().numpy(), cmap='viridis', origin='lower', aspect='auto')
    plt.colorbar(format="%+2.0f dB")
    plt.title("Spectrogram")
    plt.xlabel("Time")
    plt.ylabel("Frequency")

    # Compute and display the Mel Spectrogram
    mel_spectrogram = torchaudio.transforms.MelSpectrogram(sample_rate=sample_rate)(audio)
    plt.subplot(2, 2, 3)
    plt.imshow(mel_spectrogram.log2().squeeze().detach().numpy(), cmap='viridis', origin='lower', aspect='auto')
    plt.colorbar(format="%+2.0f dB")
    plt.title("Mel Spectrogram")
    plt.xlabel("Time")
    plt.ylabel("Mel Frequency")

    # Compute and display the Chroma feature using librosa
    try:
        import librosa
        import librosa.display
        # Convert audio tensor to numpy array for librosa processing
        audio_np = audio.numpy().flatten()
        mel_spectrogram_librosa = librosa.feature.melspectrogram(y=audio_np, sr=sample_rate)
        chroma = librosa.feature.chroma_stft(S=mel_spectrogram_librosa, sr=sample_rate)
        plt.subplot(2, 2, 4)
        librosa.display.specshow(chroma, x_axis='time', y_axis='chroma', cmap='coolwarm')
        plt.colorbar()
        plt.title("Chroma Feature")
        plt.xlabel("Time")
        plt.ylabel("Pitch Class")
    except ImportError:
        print("Librosa is required for Chroma visualization. Please install it with `pip install librosa`.")

    plt.tight_layout()
    plt.show()

    # Play the audio
    print("Playing Audio:")
    display(Audio(audio.numpy(), rate=sample_rate))

# %%
visualize_audio_features(audio_file="/content/selected_train_audio/bonafide/LA_T_1013597.flac")
# Out:
# /usr/local/lib/python3.10/dist-packages/torchaudio/functional/functional.py:584: UserWarning: At least one mel filterbank has all zero values. The value for `n_mels` (128) may be set too high. Or, the value for `n_freqs` (201) may be set too low.
#   warnings.warn(
# Playing Audio:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
visualize_audio_features(audio_file="/content/selected_train_audio/spoof/LA_T_1001871.flac")
# Out:
# /usr/local/lib/python3.10/dist-packages/torchaudio/functional/functional.py:584: UserWarning: At least one mel filterbank has all zero values. The value for `n_mels` (128) may be set too high. Or, the value for `n_freqs` (201) may be set too low.
#   warnings.warn(
# Playing Audio:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#Dataset Making Process

import os
import pandas as pd
import torch
import torchaudio
from torch.utils.data import Dataset

class ASVSpoof(Dataset):
    def __init__(self, base_dir, csv_file, target_length=64000):
        """
        Initializes the ASVSpoof dataset for WavLM.

        Args:
            base_dir (str): Base directory containing the 'bonafide' and 'spoof' subdirectories,
                            where audio files are organized by label.
            csv_file (str): Path to a CSV file with two columns, 'Filename' and 'Label', indicating
                            the filename of each audio file and its label ('bonafide' or 'spoof').
            target_length (int): Desired length (in samples) of each audio clip after padding or trimming.
                                 For a 16 kHz sampling rate, 64000 samples represent 4 seconds.
        """
        self.base_dir = base_dir
        self.target_length = target_length

        # Load the CSV file as a DataFrame and map labels to integer values
        self.data = pd.read_csv(csv_file)
        self.label_mapping = {"bonafide": 0, "spoof": 1}
        self.data['Label'] = self.data['Label'].map(self.label_mapping)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        # Retrieve the filename and label at the given index
        file_name = self.data.loc[idx, 'Filename']
        label = self.data.loc[idx, 'Label']

        # Determine the subdirectory ('bonafide' or 'spoof') based on the label
        subdir = "bonafide" if label == 0 else "spoof"

        # Construct the full path to the audio file
        file_path = os.path.join(self.base_dir, subdir, f"{file_name}.flac")

        # Load the audio file and convert it to mono if it has multiple channels
        audio, sample_rate = torchaudio.load(file_path)
        if audio.shape[0] > 1:
            audio = audio.mean(dim=0, keepdim=True)  # Convert to mono by averaging channels

        # Trim or pad the audio to the target length
        audio = self.trim_or_pad_audio(audio.squeeze())

        # Return raw audio and label; processing will happen in collate_fn
        return {
            "audio": audio,
            "label": torch.tensor(label, dtype=torch.long)
        }

    def trim_or_pad_audio(self, audio):
        """
        Pads or trims the audio tensor to match the target length.

        Args:
            audio (torch.Tensor): 1D tensor of audio samples.

        Returns:
            torch.Tensor: Audio tensor with length equal to target_length.
        """
        if len(audio) > self.target_length:
            return audio[:self.target_length]
        elif len(audio) < self.target_length:
            padding = self.target_length - len(audio)
            return torch.nn.functional.pad(audio, (0, padding))
        return audio

########################### We moved processing to Collate function to make it Faster ##########################################

# %%
from transformers import Wav2Vec2FeatureExtractor

# Initialize the Wav2Vec2FeatureExtractor for WavLM
feature_extractor = Wav2Vec2FeatureExtractor.from_pretrained("microsoft/wavlm-base")

def collate_fn(batch):
    # Extract audio and labels from the batch
    audios = [item["audio"] for item in batch]
    labels = torch.tensor([item["label"] for item in batch])

    # Use the feature extractor to process the audio
    inputs = feature_extractor(
        audios,
        sampling_rate=16000,
        return_tensors="pt",
        padding="longest"  # or "max_length" with a set max length, if needed
    )

    # Return the processed inputs and labels
    return {
        "input_values": inputs.input_values.squeeze(0),  # Mel-spectrogram feature sequences
        "attention_mask": inputs.attention_mask.squeeze(0),  # Attention mask for padding
        "labels": labels.squeeze(0)
    }


def create_dataloader(base_dir, csv_file, batch_size=4, shuffle=True):
    """
    Creates an optimized DataLoader for the ASVSpoof dataset.

    Args:
        base_dir (str): Path to base directory containing audio files in 'bonafide' and 'spoof' subdirectories.
        csv_file (str): Path to CSV file with filenames and labels.
        processor (WhisperFeatureExtractor): Processor for audio data.
        batch_size (int): Number of samples per batch.
        shuffle (bool): Whether to shuffle data.
        num_workers (int): Number of subprocesses to use for data loading.
        pin_memory (bool): Whether to use pinned memory for faster data transfer to GPU.

    Returns:
        DataLoader: Configured DataLoader for the dataset.
    """
    dataset = ASVSpoof(base_dir, csv_file, target_length = 64_000)

    return DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        collate_fn=collate_fn
    )
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]

# %%
# Configuration settings for the ASVSpoof project

# BASE_DIRS = {
#     "train": "../dataset/dataset/selected_train_audio/",
#     "val": "../dataset/dataset/selected_val_audio/",
#     "test": "../dataset/dataset/selected_test_audio/"
# }

BASE_DIRS = {
    "train": "/content/selected_train_audio/",
    "val": "/content/selected_val_audio/",
    "test": "/content/selected_test_audio/"
}

# CSV_FILES = {
#     "train": "../dataset/dataset/train_balanced_dataframe.csv",
#     "val": "../dataset/dataset/val_dataframe.csv",
#     "test": "../dataset/dataset/test_dataframe.csv"
# }

CSV_FILES = {
    "train": "/content/train_balanced_dataframe.csv",
    "val": "/content/val_dataframe.csv",
    "test": "/content/test_dataframe.csv"
}

BASE_MODEL = "facebook/wav2vec2-base"
NUM_LABELS = 1

# Set batch size
BATCH_SIZE = 48

# %% [markdown]
# ## Model Definition Wav2Vec2 For Deepfake Detection

# %%
import torch
from torch import nn
from transformers import Wav2Vec2Model

# Define Wav2Vec2Classifier for audio classification (encoder-only approach)
class Wav2Vec2Classifier(nn.Module):
    """
    A custom classifier for audio classification using the Wav2Vec2 encoder,
    fine-tuned for binary classification (e.g., real or fake audio).
    """
    def __init__(self, model_name: str, num_labels: int):
        super(Wav2Vec2Classifier, self).__init__()
        # Load Wav2Vec2 model without a classification head
        self.wav2vec2_model = Wav2Vec2Model.from_pretrained(model_name)

        # Freeze Wav2Vec2 model parameters to prevent updates during training
        for param in self.wav2vec2_model.parameters():
            param.requires_grad = False

        # Get hidden size of the Wav2Vec2 encoder
        hidden_size = self.wav2vec2_model.config.hidden_size

        # Classification head
        self.classifier = nn.Linear(hidden_size, num_labels)


    def forward(self, input_features):
        """
        Forward pass through the Wav2Vec2 encoder and classification head.

        Args:
            input_features (torch.Tensor): Preprocessed audio features tensor.

        Returns:
            torch.Tensor: Logits for each class.
        """
        # Pass inputs through Wav2Vec2 encoder to get hidden states
        outputs = self.wav2vec2_model(input_features)
        last_hidden_state = outputs.last_hidden_state  # shape (batch_size, seq_len, hidden_size)

        # Pool the outputs (e.g., take the mean over the sequence length)
        pooled_output = last_hidden_state.mean(dim=1)  # shape (batch_size, hidden_size)

        # Pass through the classifier
        logits = self.classifier(pooled_output)

        return logits

    def predict(self, input_features: torch.Tensor) -> int:
        """
        Makes a prediction based on the preprocessed audio input.

        Args:
            input_features (torch.Tensor): Preprocessed audio features tensor.

        Returns:
            int: Predicted class (0 or 1).
        """
        logits = self.forward(input_features)

        return logits

# %%
# Defining dataloader and model for training purpose

model = Wav2Vec2Classifier(model_name = BASE_MODEL, num_labels = NUM_LABELS)

train_loader = create_dataloader(BASE_DIRS["train"], CSV_FILES["train"], batch_size=BATCH_SIZE)
val_loader = create_dataloader(BASE_DIRS["val"], CSV_FILES["val"], batch_size=BATCH_SIZE)
test_loader = create_dataloader(BASE_DIRS["test"], CSV_FILES["test"], batch_size=BATCH_SIZE)


# Example of accessing data from train_loader
for batch in train_loader:
    print(batch["input_values"].shape)
    print(batch["attention_mask"].shape)
    print(batch["labels"].shape)
    break  # Print the shape of one batch and exit


# Example of accessing data from val_loader
for batch in val_loader:
    print(batch["input_values"].shape)
    print(batch["attention_mask"].shape)
    print(batch["labels"].shape)
    break  # Print the shape of one batch and exit


# Example of accessing data from test_loader
for batch in test_loader:
    print(batch["input_values"].shape)
    print(batch["attention_mask"].shape)
    print(batch["labels"].shape)
    break  # Print the shape of one batch and exit
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/configuration_utils.py:306: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(
# torch.Size([48, 64000])
# torch.Size([48])
# torch.Size([48])
# torch.Size([48, 64000])
# torch.Size([48])
# torch.Size([48])
# torch.Size([48, 64000])
# torch.Size([48])
# torch.Size([48])

# %%
# !pip install torchinfo
# Out:
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.10/dist-packages (1.8.0)

# %%
# Calculating forward and backward pass memory
# Total memory used by model parameters (in bytes)
from torchinfo import summary

# Assuming `model` is your PyTorch model
batch_size = 48  # Or the batch size you'd like to simulate
input_shape = (batch_size, 64000)  # Replace `input_shape` with your model's input dimensions

# Print the model summary
summary(model, input_size=input_shape, col_names=["input_size", "output_size", "num_params", "params_percent"])
# Out:
# ===========================================================================================================================================================
# Layer (type:depth-idx)                                  Input Shape               Output Shape              Param #                   Param %
# ===========================================================================================================================================================
# Wav2Vec2Classifier                                      [48, 64000]               [48, 1]                   --                             --
# ├─Wav2Vec2Model: 1-1                                    [48, 64000]               [48, 199, 512]            768                         0.00%
# │    └─Wav2Vec2FeatureEncoder: 2-1                      [48, 64000]               [48, 512, 199]            --                             --
# │    │    └─ModuleList: 3-1                             --                        --                        (4,200,448)                 4.45%
# │    └─Wav2Vec2FeatureProjection: 2-2                   [48, 199, 512]            [48, 199, 768]            --                             --
# │    │    └─LayerNorm: 3-2                              [48, 199, 512]            [48, 199, 512]            (1,024)                     0.00%
# │    │    └─Linear: 3-3                                 [48, 199, 512]            [48, 199, 768]            (393,984)                   0.42%
# │    │    └─Dropout: 3-4                                [48, 199, 768]            [48, 199, 768]            --                             --
# │    └─Wav2Vec2Encoder: 2-3                             [48, 199, 768]            [48, 199, 768]            --                             --
# │    │    └─Wav2Vec2PositionalConvEmbedding: 3-5        [48, 199, 768]            [48, 199, 768]            (4,719,488)                 5.00%
# │    │    └─LayerNorm: 3-6                              [48, 199, 768]            [48, 199, 768]            (1,536)                     0.00%
# │    │    └─Dropout: 3-7                                [48, 199, 768]            [48, 199, 768]            --                             --
# │    │    └─ModuleList: 3-8                             --                        --                        (85,054,464)               90.13%
# ├─Linear: 1-2                                           [48, 768]                 [48, 1]                   769                         0.00%
# ===========================================================================================================================================================
# Total params: 94,372,481
# Trainable params: 769
# Non-trainable params: 94,371,712
# Total mult-adds (G): 475.13
# ===========================================================================================================================================================
# Input size (MB): 12.29
# Forward/backward pass size (MB): 15412.10
# Params size (MB): 358.61
# Estimated Total Size (MB): 15783.00
# ===========================================================================================================================================================

# %%
import wandb

# %%
# This code is adapted from Homework 1 and changed to accomododate Wav2Vec2 Training

# Common settings and constants
LEARNING_RATE = 1e-3
WEIGHT_DECAY = 1e-2
GAMMA = 0.9  # Decay factor for the exponential scheduler
NUM_EPOCHS = 20
ACCUMULATION_STEPS = 1
CHECKPOINT_PATH = "./Wav2Vec2/wav2vec2_checkpoint.pth"
DEVICE = "cuda"
#DEVICE = "cpu"

# Enable cuDNN benchmarking for faster computation on compatible architectures
torch.backends.cudnn.benchmark = True

# Initialize Weights and Biases (wandb) logging
wandb.init(project="audio-classification", name="Wav2Vec2 Deepfake Detection")

model = model.to(DEVICE)

# Define optimizer, scheduler, and loss function
optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=GAMMA)
criterion = nn.BCEWithLogitsLoss()  # Binary classification loss function

# Mixed precision scaler
scaler = torch.amp.GradScaler("cuda")

# Lists to keep track of training and validation losses
train_losses = []
val_losses = []

# Function to load checkpoint
def load_checkpoint(checkpoint_path, model, optimizer, scheduler):
    if os.path.isfile(checkpoint_path):
        print(f"Loading checkpoint from {checkpoint_path}")
        checkpoint = torch.load(checkpoint_path)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
        start_epoch = checkpoint['epoch']
        best_val_accuracy = checkpoint['best_val_acc']
        print(f"Loading checkpoints from epoch {start_epoch+1} with best validation accuracy {best_val_accuracy:.4f}")
        return start_epoch, best_val_loss
    else:
        print("No checkpoint found. Starting training from scratch.")
        return 0, float('inf')

# Load checkpoint if available
start_epoch, best_val_loss = load_checkpoint(CHECKPOINT_PATH, model, optimizer, scheduler)
# Out:
# wandb: Currently logged in as: avinash-saxena (avinash-saxena-san-jose-state-university). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>/content/wandb/run-20241116_234602-2b2a1jub</code>
# Syncing run <strong><a href='https://wandb.ai/avinash-saxena-san-jose-state-university/audio-classification/runs/2b2a1jub' target="_blank">Wav2Vec2 Deepfake Detection</a></strong> to <a href='https://wandb.ai/avinash-saxena-san-jose-state-university/audio-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/avinash-saxena-san-jose-state-university/audio-classification' target="_blank">https://wandb.ai/avinash-saxena-san-jose-state-university/audio-classification</a>
#  View run at <a href='https://wandb.ai/avinash-saxena-san-jose-state-university/audio-classification/runs/2b2a1jub' target="_blank">https://wandb.ai/avinash-saxena-san-jose-state-university/audio-classification/runs/2b2a1jub</a>
# No checkpoint found. Starting training from scratch.

# %%
if  os.path.exists("./Wav2Vec2") == False:
    os.mkdir("./Wav2Vec2")

# %%
# Training and Validation function
def train_and_validate(model, criterion, optimizer, scheduler, num_epochs=NUM_EPOCHS, start_epoch=0, best_val_acc=0):
    model = model.to(DEVICE)
    for epoch in range(start_epoch, num_epochs):
        # Training phase
        model.train()
        print("Model is running on:", next(model.parameters()).device)

        running_loss = 0.0
        correct = 0
        total = 0

        # Improve DataLoader efficiency
        train_bar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs} [Training]", leave=False)

        optimizer.zero_grad()  # Reset gradients before each epoch
        for i, batch in enumerate(train_bar):
            inputs = batch["input_values"].to(DEVICE, non_blocking=True)
            attention_mask = batch["attention_mask"].to(DEVICE, non_blocking=True)
            labels = batch["labels"].to(DEVICE, non_blocking=True).float()  # Convert labels to float

            # Mixed precision training with autocast
            with torch.amp.autocast("cuda"):
                # Forward pass
                outputs = model(inputs)
                outputs = outputs.squeeze()  # Ensuring outputs have shape [batch_size]
                loss = criterion(outputs, labels)
                loss = loss / ACCUMULATION_STEPS  # Scale the loss for accumulation

            # Backward pass
            scaler.scale(loss).backward()

            # Update weights and zero gradients after ACCUMULATION_STEPS iterations

            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()

            # Track metrics efficiently with vectorized operations
            running_loss += loss.detach() * inputs.size(0) * ACCUMULATION_STEPS
            predicted = (outputs > 0).long()  # Use threshold of 0 for binary classification
            total += labels.size(0)
            correct += (predicted == labels.long()).sum().item()

        # Calculate training loss and accuracy
        epoch_train_loss = running_loss.item() / len(train_loader.dataset)
        epoch_train_acc = 100 * correct / total
        train_losses.append(epoch_train_loss)

        # Validation phase
        model.eval()
        val_loss = 0.0
        val_correct = 0
        val_total = 0

        with torch.no_grad():
            val_bar = tqdm(val_loader, desc="Validation", leave=False)
            for batch in val_bar:
                inputs = batch["input_values"].to(DEVICE, non_blocking=True)
                attention_mask = batch["attention_mask"].to(DEVICE, non_blocking=True)
                labels = batch["labels"].to(DEVICE, non_blocking=True).float()  # Convert labels to float

                # Mixed precision training with autocast
                with torch.amp.autocast("cuda"):
                    # Forward pass
                    outputs = model(inputs)
                    outputs = outputs.squeeze()  # Ensuring outputs have shape [batch_size]
                    loss = criterion(outputs, labels)

                # Track validation metrics efficiently
                val_loss += loss.item() * inputs.size(0)
                predicted = (outputs > 0).long()  # Use threshold of 0 for binary classification
                val_total += labels.size(0)
                val_correct += (predicted == labels.long()).sum().item()

        # Calculate validation loss and accuracy
        epoch_val_loss = val_loss / len(val_loader.dataset)
        epoch_val_acc = 100 * val_correct / val_total
        val_losses.append(epoch_val_loss)

        print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {epoch_train_loss:.4f}, Train Acc: {epoch_train_acc:.2f}%, "
              f"Val Loss: {epoch_val_loss:.4f}, Val Acc: {epoch_val_acc:.2f}%")

        # Logging to wandb
        wandb.log({
            'epoch': epoch + 1,
            'train_loss': epoch_train_loss,
            'train_accuracy': epoch_train_acc,
            'val_loss': epoch_val_loss,
            'val_accuracy': epoch_val_acc
        })

        # Save model if it has the best validation accuracy
        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            model_save_path = f"./Wav2Vec2//wav2vec2_best_val_acc_{best_val_acc:.2f}.pth"
            torch.save({
                'epoch': epoch + 1,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'scheduler_state_dict': scheduler.state_dict(),
                'best_val_acc': best_val_acc
            }, model_save_path)
            print(f"New best model saved with validation accuracy {best_val_acc:.2f}% at epoch {epoch + 1}")

        # Step the scheduler
        scheduler.step()


# Run training and validation
train_and_validate(model, criterion, optimizer, scheduler, num_epochs=NUM_EPOCHS, start_epoch=start_epoch, best_val_acc=0)

# End WandB session if using wandb
wandb.finish()
# Out:
# Model is running on: cuda:0
# Epoch 1/20, Train Loss: 0.6075, Train Acc: 80.33%, Val Loss: 0.5441, Val Acc: 77.20%
# New best model saved with validation accuracy 77.20% at epoch 1
# Model is running on: cuda:0
# Epoch 2/20, Train Loss: 0.4926, Train Acc: 88.24%, Val Loss: 0.4546, Val Acc: 84.60%
# New best model saved with validation accuracy 84.60% at epoch 2
# Model is running on: cuda:0
# Epoch 3/20, Train Loss: 0.4322, Train Acc: 88.88%, Val Loss: 0.4687, Val Acc: 78.80%
# Model is running on: cuda:0
# Epoch 4/20, Train Loss: 0.3978, Train Acc: 89.30%, Val Loss: 0.4296, Val Acc: 81.50%
# Model is running on: cuda:0
# Epoch 5/20, Train Loss: 0.3765, Train Acc: 90.08%, Val Loss: 0.4082, Val Acc: 82.20%
# Model is running on: cuda:0
# Epoch 6/20, Train Loss: 0.3567, Train Acc: 90.62%, Val Loss: 0.3823, Val Acc: 84.20%
# Model is running on: cuda:0
# Epoch 7/20, Train Loss: 0.3415, Train Acc: 90.78%, Val Loss: 0.3769, Val Acc: 84.30%
# Model is running on: cuda:0
# Epoch 8/20, Train Loss: 0.3308, Train Acc: 91.01%, Val Loss: 0.3811, Val Acc: 83.80%
# Model is running on: cuda:0
# Epoch 9/20, Train Loss: 0.3209, Train Acc: 91.28%, Val Loss: 0.3711, Val Acc: 84.20%
# Model is running on: cuda:0
# Epoch 10/20, Train Loss: 0.3140, Train Acc: 91.14%, Val Loss: 0.3657, Val Acc: 84.70%
# New best model saved with validation accuracy 84.70% at epoch 10
# Model is running on: cuda:0
# Epoch 11/20, Train Loss: 0.3075, Train Acc: 91.61%, Val Loss: 0.3590, Val Acc: 85.00%
# New best model saved with validation accuracy 85.00% at epoch 11
# Model is running on: cuda:0
# Epoch 12/20, Train Loss: 0.3005, Train Acc: 91.57%, Val Loss: 0.3346, Val Acc: 86.20%
# New best model saved with validation accuracy 86.20% at epoch 12
# Model is running on: cuda:0
# Epoch 13/20, Train Loss: 0.2938, Train Acc: 91.90%, Val Loss: 0.3451, Val Acc: 85.30%
# Model is running on: cuda:0
# Epoch 14/20, Train Loss: 0.2914, Train Acc: 92.13%, Val Loss: 0.3419, Val Acc: 85.80%
# Model is running on: cuda:0
# Epoch 15/20, Train Loss: 0.2890, Train Acc: 92.02%, Val Loss: 0.3359, Val Acc: 85.80%
# Model is running on: cuda:0
# Epoch 16/20, Train Loss: 0.2879, Train Acc: 91.86%, Val Loss: 0.3384, Val Acc: 85.70%
# Model is running on: cuda:0
# Epoch 17/20, Train Loss: 0.2834, Train Acc: 91.94%, Val Loss: 0.3339, Val Acc: 85.70%
# Model is running on: cuda:0
# Epoch 18/20, Train Loss: 0.2849, Train Acc: 92.07%, Val Loss: 0.3371, Val Acc: 85.70%
# Model is running on: cuda:0
# Epoch 19/20, Train Loss: 0.2794, Train Acc: 92.05%, Val Loss: 0.3326, Val Acc: 85.70%
# Model is running on: cuda:0
# Epoch 20/20, Train Loss: 0.2764, Train Acc: 92.15%, Val Loss: 0.3293, Val Acc: 86.00%
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>train_accuracy</td><td>▁▆▆▆▇▇▇▇▇▇██████████</td></tr><tr><td>train_loss</td><td>█▆▄▄▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▇▂▄▅▆▇▆▆▇▇█▇███████</td></tr><tr><td>val_loss</td><td>█▅▆▄▄▃▃▃▂▂▂▁▂▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>train_accuracy</td><td>92.15116</td></tr><tr><td>train_loss</td><td>0.27641</td></tr><tr><td>val_accuracy</td><td>86</td></tr><tr><td>val_loss</td><td>0.32934</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Wav2Vec2 Deepfake Detection</strong> at: <a href='https://wandb.ai/avinash-saxena-san-jose-state-university/audio-classification/runs/2b2a1jub' target="_blank">https://wandb.ai/avinash-saxena-san-jose-state-university/audio-classification/runs/2b2a1jub</a><br/> View project at: <a href='https://wandb.ai/avinash-saxena-san-jose-state-university/audio-classification' target="_blank">https://wandb.ai/avinash-saxena-san-jose-state-university/audio-classification</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241116_234602-2b2a1jub/logs</code>

# %% [markdown]
# ## Evaluating the Model on Test Dataset

# %%
# Define the device
device = "cuda" if torch.cuda.is_available() else "cpu"

# Instantiate the Wav2Vec2Classifier model
model = Wav2Vec2Classifier(model_name=BASE_MODEL, num_labels=NUM_LABELS)  # Adjust model_name and num_labels as needed
model = model.to(device)


# Set the model to evaluation mode
model.eval()


# Load the checkpoint (replace with the actual checkpoint path if needed)
checkpoint_path = "/content/Wav2Vec2/wav2vec2_best_val_acc_86.20.pth"
checkpoint = torch.load(checkpoint_path, map_location=device)

print("loading saved model")
start_epoch, best_val_loss = load_checkpoint(checkpoint_path, model, optimizer, scheduler)

# Set the model to evaluation mode
model.eval()

import torch
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from tqdm import tqdm

def evaluate_model(model, test_loader):
    model.eval()
    y_true = []
    y_pred = []

    with torch.no_grad():
        test_bar = tqdm(test_loader, desc="Testing", leave=False)
        for batch in test_bar:
            # Extract input features and labels from the batch dictionary
            input_features = batch["input_values"].to(device)  # Corrected to match your dictionary key
            labels = batch["labels"]

            # Forward pass
            logits = model(input_features).squeeze()  # Remove extra dimensions if present

            # Apply sigmoid to get probabilities
            probs = torch.sigmoid(logits)

            # Classify based on a 0.5 threshold
            predicted = (probs > 0.5).long()

            # Store predictions and labels for metrics calculation
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())

    # Calculate evaluation metrics
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)

    # Print and log the metrics
    print(f"Test Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")

    # Optional: return metrics for further analysis
    return {
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1_score": f1
    }

# Run the evaluation
test_metrics = evaluate_model(model, test_loader)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/configuration_utils.py:306: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(
# <ipython-input-56-96ce36104914>:15: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location=device)
# loading saved model
# Loading checkpoint from /content/Wav2Vec2/wav2vec2_best_val_acc_86.20.pth
# <ipython-input-53-82b0613c557d>:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path)
# Loading checkpoints from epoch 13 with best validation accuracy 86.2000
# Test Accuracy: 0.8125
# Precision: 0.9756
# Recall: 0.6410
# F1 Score: 0.7737

# %%
import pandas as pd
metrics_df = pd.DataFrame(test_metrics, index=[0])
metrics_df.to_csv("/content/Wav2Vec2/test_metrics.csv", index=False)
